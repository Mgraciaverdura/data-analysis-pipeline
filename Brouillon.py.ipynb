# %%
import calendarific
import requests
import pandas as pd
import numpy as np

BASE_URL = "https://calendarific.com/api/v2"
API_KEY = ''
with open("token_crash.py") as file: # Use file to refer to the file object
   API_KEY = file.read().strip()
country= 'ES'
year= '2019'
res = requests.get("{}/holidays?&api_key={}&country={}&year={}".format(BASE_URL,API_KEY,country,year))
res.json()
# Out:
# {'meta': {'code': 200},
#  'response': {'holidays': [{'name': "New Year's Day",
#     'description': 'New Year’s Day is the first day of the year, or January 1, in the Gregorian calendar.',
#     'date': {'iso': '2019-01-01',
#      'datetime': {'year': 2019, 'month': 1, 'day': 1}},
#     'type': ['National holiday'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Reconquest Day',
#     'description': None,
#     'date': {'iso': '2019-01-02',
#      'datetime': {'year': 2019, 'month': 1, 'day': 2}},
#     'type': ['Local holiday'],
#     'locations': 'GR',
#     'states': [{'id': 324,
#       'abbrev': 'GR',
#       'name': 'Granada',
#       'exception': None,
#       'iso': 'es-gr'}]},
#    {'name': 'Epiphany',
#     'description': 'Epiphany is a public holiday and the day most Christmas presentes are exchanged in Spain.',
#     'date': {'iso': '2019-01-06',
#      'datetime': {'year': 2019, 'month': 1, 'day': 6}},
#     'type': ['National holiday'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Epiphany observed',
#     'description': 'Epiphany observed on January 7 is a public holiday in most Spanish regions whenever January 6 is on a Sunday.',
#     'date': {'iso': '2019-01-07',
#      'datetime': {'year': 2019, 'month': 1, 'day': 7}},
#     'type': ['Common local holiday'],
#     'locations': 'AN, AR, O, CN, CL, EX, MU, NA, CE, M, ML',
#     'states': [{'id': 212,
#       'abbrev': 'AN',
#       'name': 'Andalusia',
#       'exception': None,
#       'iso': 'es-an'},
#      {'id': 213,
#       'abbrev': 'AR',
#       'name': 'Aragon',
#       'exception': None,
#       'iso': 'es-ar'},
#      {'id': 288,
#       'abbrev': 'O',
#       'name': 'Asturias',
#       'exception': None,
#       'iso': 'es-as'},
#      {'id': 291,
#       'abbrev': 'CN',
#       'name': 'Canary Islands',
#       'exception': None,
#       'iso': 'es-cn'},
#      {'id': 294,
#       'abbrev': 'CL',
#       'name': 'Castile-Leon',
#       'exception': None,
#       'iso': 'es-cl'},
#      {'id': 296,
#       'abbrev': 'EX',
#       'name': 'Extremadura',
#       'exception': None,
#       'iso': 'es-ex'},
#      {'id': 338,
#       'abbrev': 'MU',
#       'name': 'Murcia',
#       'exception': None,
#       'iso': 'es-mu'},
#      {'id': 339,
#       'abbrev': 'NA',
#       'name': 'Navarre',
#       'exception': None,
#       'iso': 'es-na'},
#      {'id': 303,
#       'abbrev': 'CE',
#       'name': 'Ceuta',
#       'exception': None,
#       'iso': 'es-ce'},
#      {'id': 299,
#       'abbrev': 'M',
#       'name': 'Madrid',
#       'exception': None,
#       'iso': 'es-md'},
#      {'id': 304,
#       'abbrev': 'ML',
#       'name': 'Melilla',
#       'exception': None,
#       'iso': 'es-ml'}]},
#    {'name': "St. Valero's Feast",
#     'description': None,
#     'date': {'iso': '2019-01-29',
#      'datetime': {'year': 2019, 'month': 1, 'day': 29}},
#     'type': ['Local holiday'],
#     'locations': 'Z',
#     'states': [{'id': 355,
#       'abbrev': 'Z',
#       'name': 'Zaragoza',
#       'exception': None,
#       'iso': 'es-z'}]},
#    {'name': "Valentine's Day",
#     'description': 'Valentine’s Day is a special time to celebrate love, romance and friendship.',
#     'date': {'iso': '2019-02-14',
#      'datetime': {'year': 2019, 'month': 2, 'day': 14}},
#     'type': ['Observance'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Day of Andalucía',
#     'description': 'The Day of Andalucía, also known as Andalucía Day, is an annual public holiday in the Andalucía autonomous community in Spain on February 28.',
#     'date': {'iso': '2019-02-28',
#      'datetime': {'year': 2019, 'month': 2, 'day': 28}},
#     'type': ['Local holiday'],
#     'locations': 'AN',
#     'states': [{'id': 212,
#       'abbrev': 'AN',
#       'name': 'Andalusia',
#       'exception': None,
#       'iso': 'es-an'}]},
#    {'name': 'Day of the Balearic Islands',
#     'description': "The Day of the Balearic Islands is held on March 1 to remember the date when the Balearic Islands' Statute of Autonomy came into effect. It is a local public holiday in this area in Spain.",
#     'date': {'iso': '2019-03-01',
#      'datetime': {'year': 2019, 'month': 3, 'day': 1}},
#     'type': ['Local holiday'],
#     'locations': 'IB',
#     'states': [{'id': 289,
#       'abbrev': 'IB',
#       'name': 'Balearic Islands',
#       'exception': None,
#       'iso': 'es-ib'}]},
#    {'name': 'Fifth of March',
#     'description': None,
#     'date': {'iso': '2019-03-05',
#      'datetime': {'year': 2019, 'month': 3, 'day': 5}},
#     'type': ['Local holiday'],
#     'locations': 'Z',
#     'states': [{'id': 355,
#       'abbrev': 'Z',
#       'name': 'Zaragoza',
#       'exception': None,
#       'iso': 'es-z'}]},
#    {'name': 'Ash Wednesday',
#     'description': 'Ash Wednesday marks the first day of Lent in western Christian churches.',
#     'date': {'iso': '2019-03-06',
#      'datetime': {'year': 2019, 'month': 3, 'day': 6}},
#     'type': ['Observance'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'San Jose',
#     'description': "Saint Joseph's Day honors St Joseph, the Virgin Mary's spouse. It is a public holiday in some parts of Spain on March 19 each year.",
#     'date': {'iso': '2019-03-19',
#      'datetime': {'year': 2019, 'month': 3, 'day': 19}},
#     'type': ['Common local holiday'],
#     'locations': 'VC, GA, MU, NA, PV',
#     'states': [{'id': 302,
#       'abbrev': 'VC',
#       'name': 'Valencia',
#       'exception': None,
#       'iso': 'es-vc'},
#      {'id': 297,
#       'abbrev': 'GA',
#       'name': 'Galicia',
#       'exception': None,
#       'iso': 'es-ga'},
#      {'id': 300,
#       'abbrev': 'MU',
#       'name': 'Murcia',
#       'exception': None,
#       'iso': 'es-mc'},
#      {'id': 301,
#       'abbrev': 'NA',
#       'name': 'Navarre',
#       'exception': None,
#       'iso': 'es-nc'},
#      {'id': 290,
#       'abbrev': 'PV',
#       'name': 'Basque Country',
#       'exception': None,
#       'iso': 'es-pv'}]},
#    {'name': 'March Equinox',
#     'description': None,
#     'date': {'iso': '2019-03-20T22:58:32+01:00',
#      'datetime': {'year': 2019,
#       'month': 3,
#       'day': 20,
#       'hour': 22,
#       'minute': 58,
#       'second': 32},
#      'timezone': {'offset': '+01:00',
#       'zoneabb': 'CET',
#       'zoneoffset': 3600,
#       'zonedst': 0,
#       'zonetotaloffset': 3600}},
#     'type': ['Season'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Daylight Saving Time starts',
#     'description': None,
#     'date': {'iso': '2019-03-31T02:00:00+01:00',
#      'datetime': {'year': 2019,
#       'month': 3,
#       'day': 31,
#       'hour': 2,
#       'minute': 0,
#       'second': 0},
#      'timezone': {'offset': '+01:00',
#       'zoneabb': 'CET',
#       'zoneoffset': 3600,
#       'zonedst': 0,
#       'zonetotaloffset': 3600}},
#     'type': ['Clock change/Daylight Saving Time'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Palm Sunday',
#     'description': 'Palm Sunday is a Christian feast that commemorates Jesus Christ’s entry into Jerusalem. It is also the start of Holy Week.',
#     'date': {'iso': '2019-04-14',
#      'datetime': {'year': 2019, 'month': 4, 'day': 14}},
#     'type': ['Observance'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Maundy Thursday',
#     'description': 'Maundy Thursday is a Christian observance on the Thursday during Holy Week. It is the day before Good Friday.',
#     'date': {'iso': '2019-04-18',
#      'datetime': {'year': 2019, 'month': 4, 'day': 18}},
#     'type': ['Common local holiday'],
#     'locations': '16 states',
#     'states': [{'id': 212,
#       'abbrev': 'AN',
#       'name': 'Andalusia',
#       'exception': None,
#       'iso': 'es-an'},
#      {'id': 213,
#       'abbrev': 'AR',
#       'name': 'Aragon',
#       'exception': None,
#       'iso': 'es-ar'},
#      {'id': 288,
#       'abbrev': 'O',
#       'name': 'Asturias',
#       'exception': None,
#       'iso': 'es-as'},
#      {'id': 289,
#       'abbrev': 'IB',
#       'name': 'Balearic Islands',
#       'exception': None,
#       'iso': 'es-ib'},
#      {'id': 290,
#       'abbrev': 'PV',
#       'name': 'Basque Country',
#       'exception': None,
#       'iso': 'es-pv'},
#      {'id': 291,
#       'abbrev': 'CN',
#       'name': 'Canary Islands',
#       'exception': None,
#       'iso': 'es-cn'},
#      {'id': 293,
#       'abbrev': 'CM',
#       'name': 'Castile-La Mancha',
#       'exception': None,
#       'iso': 'es-cm'},
#      {'id': 294,
#       'abbrev': 'CL',
#       'name': 'Castile-Leon',
#       'exception': None,
#       'iso': 'es-cl'},
#      {'id': 303,
#       'abbrev': 'CE',
#       'name': 'Ceuta',
#       'exception': None,
#       'iso': 'es-ce'},
#      {'id': 296,
#       'abbrev': 'EX',
#       'name': 'Extremadura',
#       'exception': None,
#       'iso': 'es-ex'},
#      {'id': 297,
#       'abbrev': 'GA',
#       'name': 'Galicia',
#       'exception': None,
#       'iso': 'es-ga'},
#      {'id': 299,
#       'abbrev': 'M',
#       'name': 'Madrid',
#       'exception': None,
#       'iso': 'es-md'},
#      {'id': 304,
#       'abbrev': 'ML',
#       'name': 'Melilla',
#       'exception': None,
#       'iso': 'es-ml'},
#      {'id': 300,
#       'abbrev': 'MU',
#       'name': 'Murcia',
#       'exception': None,
#       'iso': 'es-mc'},
#      {'id': 301,
#       'abbrev': 'NA',
#       'name': 'Navarre',
#       'exception': None,
#       'iso': 'es-nc'},
#      {'id': 298,
#       'abbrev': 'LO',
#       'name': 'La Rioja',
#       'exception': None,
#       'iso': 'es-ri'}]},
#    {'name': 'Good Friday',
#     'description': 'Good Friday is a global Christian observance two days before Easter Sunday.',
#     'date': {'iso': '2019-04-19',
#      'datetime': {'year': 2019, 'month': 4, 'day': 19}},
#     'type': ['National holiday'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Easter Sunday',
#     'description': 'Easter Sunday commemorates Jesus Christ’s resurrection, according to Christian belief.',
#     'date': {'iso': '2019-04-21',
#      'datetime': {'year': 2019, 'month': 4, 'day': 21}},
#     'type': ['Observance'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Easter Monday',
#     'description': 'Easter Monday is the day after Easter Sunday.',
#     'date': {'iso': '2019-04-22',
#      'datetime': {'year': 2019, 'month': 4, 'day': 22}},
#     'type': ['Common local holiday'],
#     'locations': 'IB, S, CM, CT, VC, NA, PV, LO',
#     'states': [{'id': 289,
#       'abbrev': 'IB',
#       'name': 'Balearic Islands',
#       'exception': None,
#       'iso': 'es-ib'},
#      {'id': 292,
#       'abbrev': 'S',
#       'name': 'Cantabria',
#       'exception': None,
#       'iso': 'es-cb'},
#      {'id': 293,
#       'abbrev': 'CM',
#       'name': 'Castile-La Mancha',
#       'exception': None,
#       'iso': 'es-cm'},
#      {'id': 295,
#       'abbrev': 'CT',
#       'name': 'Catalonia',
#       'exception': None,
#       'iso': 'es-ct'},
#      {'id': 302,
#       'abbrev': 'VC',
#       'name': 'Valencia',
#       'exception': None,
#       'iso': 'es-vc'},
#      {'id': 301,
#       'abbrev': 'NA',
#       'name': 'Navarre',
#       'exception': None,
#       'iso': 'es-nc'},
#      {'id': 290,
#       'abbrev': 'PV',
#       'name': 'Basque Country',
#       'exception': None,
#       'iso': 'es-pv'},
#      {'id': 298,
#       'abbrev': 'LO',
#       'name': 'La Rioja',
#       'exception': None,
#       'iso': 'es-ri'}]},
#    {'name': 'Day of Aragón',
#     'description': "The Day of Aragon celebrates the Spanish region of Aragon's culture and history. It is an annual local public holiday on April 23.",
#     'date': {'iso': '2019-04-23',
#      'datetime': {'year': 2019, 'month': 4, 'day': 23}},
#     'type': ['Local holiday'],
#     'locations': 'AR',
#     'states': [{'id': 213,
#       'abbrev': 'AR',
#       'name': 'Aragon',
#       'exception': None,
#       'iso': 'es-ar'}]},
#    {'name': "St George's Day",
#     'description': "St George's Day is an occasion for people in Catalonia to give loved ones a rose and a book.",
#     'date': {'iso': '2019-04-23',
#      'datetime': {'year': 2019, 'month': 4, 'day': 23}},
#     'type': ['Local observance'],
#     'locations': 'CT',
#     'states': [{'id': 295,
#       'abbrev': 'CT',
#       'name': 'Catalonia',
#       'exception': None,
#       'iso': 'es-ct'}]},
#    {'name': 'Castile and León Day',
#     'description': 'Castile and León Day is celebrated in the Spanish autonomous community of Castile and León on April 23 every year.',
#     'date': {'iso': '2019-04-23',
#      'datetime': {'year': 2019, 'month': 4, 'day': 23}},
#     'type': ['Local holiday'],
#     'locations': 'CL',
#     'states': [{'id': 294,
#       'abbrev': 'CL',
#       'name': 'Castile-Leon',
#       'exception': None,
#       'iso': 'es-cl'}]},
#    {'name': 'Labor Day / May Day',
#     'description': 'May Day, or Labor Day, is a day off for workers in many countries around the world.',
#     'date': {'iso': '2019-05-01',
#      'datetime': {'year': 2019, 'month': 5, 'day': 1}},
#     'type': ['National holiday'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Day of Madrid',
#     'description': 'The Day of the Autonomous Community of Madrid, Spain, marks the anniversary of an uprising against French troops in Madrid. It is an annual local public holiday on May 2.',
#     'date': {'iso': '2019-05-02',
#      'datetime': {'year': 2019, 'month': 5, 'day': 2}},
#     'type': ['Local holiday'],
#     'locations': 'M',
#     'states': [{'id': 299,
#       'abbrev': 'M',
#       'name': 'Madrid',
#       'exception': None,
#       'iso': 'es-md'}]},
#    {'name': "Mothers' Day",
#     'description': 'One of Spain’s most popular and festive family occasions is Mothers’ Day on the first Sunday in May.',
#     'date': {'iso': '2019-05-05',
#      'datetime': {'year': 2019, 'month': 5, 'day': 5}},
#     'type': ['Observance'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Feast Day of St Isidore',
#     'description': None,
#     'date': {'iso': '2019-05-15',
#      'datetime': {'year': 2019, 'month': 5, 'day': 15}},
#     'type': ['Local holiday'],
#     'locations': 'M',
#     'states': [{'id': 299,
#       'abbrev': 'M',
#       'name': 'Madrid',
#       'exception': None,
#       'iso': 'es-md'}]},
#    {'name': 'Galicia Literature Day',
#     'description': 'Galician Literature Day is a local public holiday annually celebrated in autonomous community of Galicia in Spain on May 17. It commemorates writers who wrote in the Galician language.',
#     'date': {'iso': '2019-05-17',
#      'datetime': {'year': 2019, 'month': 5, 'day': 17}},
#     'type': ['Local holiday'],
#     'locations': 'GA',
#     'states': [{'id': 297,
#       'abbrev': 'GA',
#       'name': 'Galicia',
#       'exception': None,
#       'iso': 'es-ga'}]},
#    {'name': 'Day of the Canary Islands',
#     'description': "The Day of the Canary Islands marks the anniversary of the autonomous Canary Islands Parliament's first session. It is a local public holiday on the Canary Islands on May 30 each year.",
#     'date': {'iso': '2019-05-30',
#      'datetime': {'year': 2019, 'month': 5, 'day': 30}},
#     'type': ['Local holiday'],
#     'locations': 'CN',
#     'states': [{'id': 291,
#       'abbrev': 'CN',
#       'name': 'Canary Islands',
#       'exception': None,
#       'iso': 'es-cn'}]},
#    {'name': 'Day of Castile-La Mancha',
#     'description': "The Day of the Region of Castilla-La Mancha marks the anniversary of when Castilla-La Mancha's first regional courts were opened. It is an annual public holiday in this Spanish region on May 31.",
#     'date': {'iso': '2019-05-31',
#      'datetime': {'year': 2019, 'month': 5, 'day': 31}},
#     'type': ['Local holiday'],
#     'locations': 'CM',
#     'states': [{'id': 293,
#       'abbrev': 'CM',
#       'name': 'Castile-La Mancha',
#       'exception': None,
#       'iso': 'es-cm'}]},
#    {'name': 'Whit Sunday/Pentecost',
#     'description': 'Many Christians all over the world annually observe Pentecost, also known as Whitsunday or Whit Sunday.',
#     'date': {'iso': '2019-06-09',
#      'datetime': {'year': 2019, 'month': 6, 'day': 9}},
#     'type': ['Observance'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Whit Monday',
#     'description': 'Whit Monday, or Pentecost Monday, is a Christian holiday that falls on the day after Pentecost, which is also known as Whit Sunday or Whitsunday.',
#     'date': {'iso': '2019-06-10',
#      'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#     'type': ['Local holiday'],
#     'locations': 'B',
#     'states': [{'id': 314,
#       'abbrev': 'B',
#       'name': 'Barcelona',
#       'exception': None,
#       'iso': 'es-b'}]},
#    {'name': 'Day of Murcia',
#     'description': "The Day of the Region of Murcia marks the anniversary of when the autonomy of Murcia's statutes was approved. It is an annual public holiday in Murcia, Spain, on June 9.",
#     'date': {'iso': '2019-06-10',
#      'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#     'type': ['Local holiday'],
#     'locations': 'MU',
#     'states': [{'id': 300,
#       'abbrev': 'MU',
#       'name': 'Murcia',
#       'exception': None,
#       'iso': 'es-mc'}]},
#    {'name': 'Day of Murcia observed',
#     'description': "The Day of the Region of Murcia marks the anniversary of when the autonomy of Murcia's statutes was approved. It is an annual public holiday in Murcia, Spain, on June 9.",
#     'date': {'iso': '2019-06-10',
#      'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#     'type': ['Local holiday'],
#     'locations': 'MU',
#     'states': [{'id': 300,
#       'abbrev': 'MU',
#       'name': 'Murcia',
#       'exception': None,
#       'iso': 'es-mc'}]},
#    {'name': 'Day of La Rioja',
#     'description': 'The Day of La Rioja is an annual public holiday in the Spanish autonomous community of La Rioja on June 9.',
#     'date': {'iso': '2019-06-10',
#      'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#     'type': ['Local holiday'],
#     'locations': 'LO',
#     'states': [{'id': 298,
#       'abbrev': 'LO',
#       'name': 'La Rioja',
#       'exception': None,
#       'iso': 'es-ri'}]},
#    {'name': 'Day of La Rioja observed',
#     'description': 'The Day of La Rioja is an annual public holiday in the Spanish autonomous community of La Rioja on June 9.',
#     'date': {'iso': '2019-06-10',
#      'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#     'type': ['Local holiday'],
#     'locations': 'LO',
#     'states': [{'id': 298,
#       'abbrev': 'LO',
#       'name': 'La Rioja',
#       'exception': None,
#       'iso': 'es-ri'}]},
#    {'name': 'San Antonio',
#     'description': "The Day of Saint Anthony of Padua marks the anniversary of St Anthony's death. It is a local public holiday in Ceuta, Spain, on June 13 each year.",
#     'date': {'iso': '2019-06-13',
#      'datetime': {'year': 2019, 'month': 6, 'day': 13}},
#     'type': ['Local holiday'],
#     'locations': 'CE',
#     'states': [{'id': 303,
#       'abbrev': 'CE',
#       'name': 'Ceuta',
#       'exception': None,
#       'iso': 'es-ce'}]},
#    {'name': 'Corpus Christi',
#     'description': 'Corpus Christi is a Christian feast in honor of the Holy Eucharist.',
#     'date': {'iso': '2019-06-20',
#      'datetime': {'year': 2019, 'month': 6, 'day': 20}},
#     'type': ['Local holiday'],
#     'locations': 'CM, GR',
#     'states': [{'id': 293,
#       'abbrev': 'CM',
#       'name': 'Castile-La Mancha',
#       'exception': None,
#       'iso': 'es-cm'},
#      {'id': 324,
#       'abbrev': 'GR',
#       'name': 'Granada',
#       'exception': None,
#       'iso': 'es-gr'}]},
#    {'name': 'June Solstice',
#     'description': None,
#     'date': {'iso': '2019-06-21T17:54:14+02:00',
#      'datetime': {'year': 2019,
#       'month': 6,
#       'day': 21,
#       'hour': 17,
#       'minute': 54,
#       'second': 14},
#      'timezone': {'offset': '+02:00',
#       'zoneabb': 'CEST',
#       'zoneoffset': 3600,
#       'zonedst': 3600,
#       'zonetotaloffset': 7200}},
#     'type': ['Season'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Saint John the Baptist Day',
#     'description': 'Saint John the Baptist Day is annually held on June 24 to honor the life of St John, an early Christian saint. It is a public holiday in Catalonia, Spain.',
#     'date': {'iso': '2019-06-24',
#      'datetime': {'year': 2019, 'month': 6, 'day': 24}},
#     'type': ['Local holiday'],
#     'locations': 'CT',
#     'states': [{'id': 295,
#       'abbrev': 'CT',
#       'name': 'Catalonia',
#       'exception': None,
#       'iso': 'es-ct'}]},
#    {'name': 'Feast of Saint James the Apostle',
#     'description': "Saint James' Day is an occasion to honor the life and deeds of one of Jesus' disciples. It is a public holiday in the autonomous communities of the Basque Country and Galicia in Spain on July 25.",
#     'date': {'iso': '2019-07-25',
#      'datetime': {'year': 2019, 'month': 7, 'day': 25}},
#     'type': ['Common local holiday'],
#     'locations': 'GA, S, PV',
#     'states': [{'id': 297,
#       'abbrev': 'GA',
#       'name': 'Galicia',
#       'exception': None,
#       'iso': 'es-ga'},
#      {'id': 292,
#       'abbrev': 'S',
#       'name': 'Cantabria',
#       'exception': None,
#       'iso': 'es-cb'},
#      {'id': 290,
#       'abbrev': 'PV',
#       'name': 'Basque Country',
#       'exception': None,
#       'iso': 'es-pv'}]},
#    {'name': 'The Day of Our Lady of Africa',
#     'description': 'The Day of Our Lady of Africa honors the patron saint of the city of Ceuta. It is a public holiday in this Spanish city on August 5.',
#     'date': {'iso': '2019-08-05',
#      'datetime': {'year': 2019, 'month': 8, 'day': 5}},
#     'type': ['Local holiday'],
#     'locations': 'CE',
#     'states': [{'id': 303,
#       'abbrev': 'CE',
#       'name': 'Ceuta',
#       'exception': None,
#       'iso': 'es-ce'}]},
#    {'name': 'The Day of Cantabria',
#     'description': 'The Day of Cantabria celebrates the history, culture and language of the Cantabrian region of Spain. It is annually held on the second Sunday of August.',
#     'date': {'iso': '2019-08-11',
#      'datetime': {'year': 2019, 'month': 8, 'day': 11}},
#     'type': ['Local observance'],
#     'locations': 'S',
#     'states': [{'id': 292,
#       'abbrev': 'S',
#       'name': 'Cantabria',
#       'exception': None,
#       'iso': 'es-cb'}]},
#    {'name': 'Eid al-Adha',
#     'description': 'Eid al-Adha (Id ul-Adha) is an Islamic festival falling on the 10th day of the month of Dhul Hijja (Thou al-Hijja) to commemorate the willingness of Ibrahim (Abraham) to sacrifice his son.',
#     'date': {'iso': '2019-08-12',
#      'datetime': {'year': 2019, 'month': 8, 'day': 12}},
#     'type': ['Local holiday'],
#     'locations': 'CE',
#     'states': [{'id': 303,
#       'abbrev': 'CE',
#       'name': 'Ceuta',
#       'exception': None,
#       'iso': 'es-ce'}]},
#    {'name': 'Eid al-Adha',
#     'description': 'Eid al-Adha (Id ul-Adha) is an Islamic festival falling on the 10th day of the month of Dhul Hijja (Thou al-Hijja) to commemorate the willingness of Ibrahim (Abraham) to sacrifice his son.',
#     'date': {'iso': '2019-08-12',
#      'datetime': {'year': 2019, 'month': 8, 'day': 12}},
#     'type': ['Local holiday'],
#     'locations': 'ML',
#     'states': [{'id': 304,
#       'abbrev': 'ML',
#       'name': 'Melilla',
#       'exception': None,
#       'iso': 'es-ml'}]},
#    {'name': 'Assumption of Mary',
#     'description': 'The Christian feast of the Assumption of Mary is on or around Aug 15 in most countries. A few celebrate Assumption Day at other times of the year.',
#     'date': {'iso': '2019-08-15',
#      'datetime': {'year': 2019, 'month': 8, 'day': 15}},
#     'type': ['National holiday'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Day of the Independent City of Ceuta',
#     'description': 'The Day of Ceuta is celebrated as a local public holiday in the city of Ceuta in Spain on September 2 each year. This date commemorates when Pedro de Menezes (Meneses) took control of Ceuta.',
#     'date': {'iso': '2019-09-02',
#      'datetime': {'year': 2019, 'month': 9, 'day': 2}},
#     'type': ['Local holiday'],
#     'locations': 'CE',
#     'states': [{'id': 303,
#       'abbrev': 'CE',
#       'name': 'Ceuta',
#       'exception': None,
#       'iso': 'es-ce'}]},
#    {'name': 'Day of Asturias',
#     'description': 'The Day of Asturias commemorates the Virgin of Covadonga and the Battle of Covadonga. It is an annual local public holiday in the autonomous community of Asturias in Spain on September 8.',
#     'date': {'iso': '2019-09-08',
#      'datetime': {'year': 2019, 'month': 9, 'day': 8}},
#     'type': ['Local holiday'],
#     'locations': 'O',
#     'states': [{'id': 288,
#       'abbrev': 'O',
#       'name': 'Asturias',
#       'exception': None,
#       'iso': 'es-as'}]},
#    {'name': 'Day of Extremadura',
#     'description': "The Day of Extremadura marks the anniversary of the Virgin Mary's birth. It is a local public holiday in Extremadura, Spain, on September 8.",
#     'date': {'iso': '2019-09-08',
#      'datetime': {'year': 2019, 'month': 9, 'day': 8}},
#     'type': ['Local holiday'],
#     'locations': 'EX',
#     'states': [{'id': 296,
#       'abbrev': 'EX',
#       'name': 'Extremadura',
#       'exception': None,
#       'iso': 'es-ex'}]},
#    {'name': 'Virgin of the Victory',
#     'description': None,
#     'date': {'iso': '2019-09-08',
#      'datetime': {'year': 2019, 'month': 9, 'day': 8}},
#     'type': ['Local holiday'],
#     'locations': 'ML',
#     'states': [{'id': 304,
#       'abbrev': 'ML',
#       'name': 'Melilla',
#       'exception': None,
#       'iso': 'es-ml'}]},
#    {'name': 'Day of Asturias observed',
#     'description': 'The Day of Asturias commemorates the Virgin of Covadonga and the Battle of Covadonga. It is an annual local public holiday in the autonomous community of Asturias in Spain on September 8.',
#     'date': {'iso': '2019-09-09',
#      'datetime': {'year': 2019, 'month': 9, 'day': 9}},
#     'type': ['Local holiday'],
#     'locations': 'O',
#     'states': [{'id': 288,
#       'abbrev': 'O',
#       'name': 'Asturias',
#       'exception': None,
#       'iso': 'es-as'}]},
#    {'name': 'Day of Extremadura observed',
#     'description': "The Day of Extremadura marks the anniversary of the Virgin Mary's birth. It is a local public holiday in Extremadura, Spain, on September 8.",
#     'date': {'iso': '2019-09-09',
#      'datetime': {'year': 2019, 'month': 9, 'day': 9}},
#     'type': ['Local holiday'],
#     'locations': 'EX',
#     'states': [{'id': 296,
#       'abbrev': 'EX',
#       'name': 'Extremadura',
#       'exception': None,
#       'iso': 'es-ex'}]},
#    {'name': 'Virgin of the Victory observed',
#     'description': None,
#     'date': {'iso': '2019-09-09',
#      'datetime': {'year': 2019, 'month': 9, 'day': 9}},
#     'type': ['Local holiday'],
#     'locations': 'ML',
#     'states': [{'id': 304,
#       'abbrev': 'ML',
#       'name': 'Melilla',
#       'exception': None,
#       'iso': 'es-ml'}]},
#    {'name': 'Day of Catalonia',
#     'description': 'The Day of Catalonia commemorates the end of the siege of Barcelona in 1714. It is a local public holiday in Barcelona, Spain, on September 11.',
#     'date': {'iso': '2019-09-11',
#      'datetime': {'year': 2019, 'month': 9, 'day': 11}},
#     'type': ['Local holiday'],
#     'locations': 'CT',
#     'states': [{'id': 295,
#       'abbrev': 'CT',
#       'name': 'Catalonia',
#       'exception': None,
#       'iso': 'es-ct'}]},
#    {'name': 'Nuestra Señora de la Bien Aparecida',
#     'description': None,
#     'date': {'iso': '2019-09-15',
#      'datetime': {'year': 2019, 'month': 9, 'day': 15}},
#     'type': ['Local holiday'],
#     'locations': 'S',
#     'states': [{'id': 292,
#       'abbrev': 'S',
#       'name': 'Cantabria',
#       'exception': None,
#       'iso': 'es-cb'}]},
#    {'name': 'Day of Melilla',
#     'description': 'The Day of Melilla marks the anniversary of the storming of the city in 1497 and is a public holiday in Melilla, Spain.',
#     'date': {'iso': '2019-09-17',
#      'datetime': {'year': 2019, 'month': 9, 'day': 17}},
#     'type': ['Local holiday'],
#     'locations': 'ML',
#     'states': [{'id': 304,
#       'abbrev': 'ML',
#       'name': 'Melilla',
#       'exception': None,
#       'iso': 'es-ml'}]},
#    {'name': 'September Equinox',
#     'description': None,
#     'date': {'iso': '2019-09-23T09:50:13+02:00',
#      'datetime': {'year': 2019,
#       'month': 9,
#       'day': 23,
#       'hour': 9,
#       'minute': 50,
#       'second': 13},
#      'timezone': {'offset': '+02:00',
#       'zoneabb': 'CEST',
#       'zoneoffset': 3600,
#       'zonedst': 3600,
#       'zonetotaloffset': 7200}},
#     'type': ['Season'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Day of the Valencian Community',
#     'description': 'The Day of the Valencian Community is a local public holiday in Valencia, Spain, on October 9 each year. It celebrates Valencian culture and history.',
#     'date': {'iso': '2019-10-09',
#      'datetime': {'year': 2019, 'month': 10, 'day': 9}},
#     'type': ['Local holiday'],
#     'locations': 'VC',
#     'states': [{'id': 302,
#       'abbrev': 'VC',
#       'name': 'Valencia',
#       'exception': None,
#       'iso': 'es-vc'}]},
#    {'name': 'Hispanic Day',
#     'description': 'Hispanic Day marks the anniversary of the date that Christopher Columbus first set foot in the Americas. It is a public holiday in Spain on October 12.',
#     'date': {'iso': '2019-10-12',
#      'datetime': {'year': 2019, 'month': 10, 'day': 12}},
#     'type': ['National holiday'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Daylight Saving Time ends',
#     'description': None,
#     'date': {'iso': '2019-10-27T03:00:00+02:00',
#      'datetime': {'year': 2019,
#       'month': 10,
#       'day': 27,
#       'hour': 3,
#       'minute': 0,
#       'second': 0},
#      'timezone': {'offset': '+02:00',
#       'zoneabb': 'CEST',
#       'zoneoffset': 3600,
#       'zonedst': 3600,
#       'zonetotaloffset': 7200}},
#     'type': ['Clock change/Daylight Saving Time'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': "All Saints' Day",
#     'description': "Many churches honor all their saints on All Saints' Day, also known as All Hallows' Day.",
#     'date': {'iso': '2019-11-01',
#      'datetime': {'year': 2019, 'month': 11, 'day': 1}},
#     'type': ['National holiday'],
#     'locations': 'CL, AN, AR, O, EX, CN, S, CE, M, ML',
#     'states': [{'id': 294,
#       'abbrev': 'CL',
#       'name': 'Castile-Leon',
#       'exception': None,
#       'iso': 'es-cl'},
#      {'id': 212,
#       'abbrev': 'AN',
#       'name': 'Andalusia',
#       'exception': None,
#       'iso': 'es-an'},
#      {'id': 213,
#       'abbrev': 'AR',
#       'name': 'Aragon',
#       'exception': None,
#       'iso': 'es-ar'},
#      {'id': 288,
#       'abbrev': 'O',
#       'name': 'Asturias',
#       'exception': None,
#       'iso': 'es-as'},
#      {'id': 296,
#       'abbrev': 'EX',
#       'name': 'Extremadura',
#       'exception': None,
#       'iso': 'es-ex'},
#      {'id': 291,
#       'abbrev': 'CN',
#       'name': 'Canary Islands',
#       'exception': None,
#       'iso': 'es-cn'},
#      {'id': 292,
#       'abbrev': 'S',
#       'name': 'Cantabria',
#       'exception': None,
#       'iso': 'es-cb'},
#      {'id': 303,
#       'abbrev': 'CE',
#       'name': 'Ceuta',
#       'exception': None,
#       'iso': 'es-ce'},
#      {'id': 299,
#       'abbrev': 'M',
#       'name': 'Madrid',
#       'exception': None,
#       'iso': 'es-md'},
#      {'id': 304,
#       'abbrev': 'ML',
#       'name': 'Melilla',
#       'exception': None,
#       'iso': 'es-ml'}]},
#    {'name': "All Saints' Day",
#     'description': "Many churches honor all their saints on All Saints' Day, also known as All Hallows' Day.",
#     'date': {'iso': '2019-11-01',
#      'datetime': {'year': 2019, 'month': 11, 'day': 1}},
#     'type': ['National holiday'],
#     'locations': 'All except AN, AR, O, CN, S, CL, EX, M, ML',
#     'states': [{'id': 289,
#       'abbrev': 'IB',
#       'name': 'Balearic Islands',
#       'exception': None,
#       'iso': 'es-ib'},
#      {'id': 290,
#       'abbrev': 'PV',
#       'name': 'Basque Country',
#       'exception': None,
#       'iso': 'es-pv'},
#      {'id': 293,
#       'abbrev': 'CM',
#       'name': 'Castile-La Mancha',
#       'exception': None,
#       'iso': 'es-cm'},
#      {'id': 295,
#       'abbrev': 'CT',
#       'name': 'Catalonia',
#       'exception': None,
#       'iso': 'es-ct'},
#      {'id': 297,
#       'abbrev': 'GA',
#       'name': 'Galicia',
#       'exception': None,
#       'iso': 'es-ga'},
#      {'id': 298,
#       'abbrev': 'LO',
#       'name': 'La Rioja',
#       'exception': None,
#       'iso': 'es-ri'},
#      {'id': 300,
#       'abbrev': 'MU',
#       'name': 'Murcia',
#       'exception': None,
#       'iso': 'es-mc'},
#      {'id': 301,
#       'abbrev': 'NA',
#       'name': 'Navarre',
#       'exception': None,
#       'iso': 'es-nc'},
#      {'id': 302,
#       'abbrev': 'VC',
#       'name': 'Valencia',
#       'exception': None,
#       'iso': 'es-vc'},
#      {'id': 303,
#       'abbrev': 'CE',
#       'name': 'Ceuta',
#       'exception': None,
#       'iso': 'es-ce'},
#      {'id': 306,
#       'abbrev': 'VI',
#       'name': 'Álava',
#       'exception': None,
#       'iso': 'es-vi'},
#      {'id': 307,
#       'abbrev': 'AB',
#       'name': 'Albacete',
#       'exception': None,
#       'iso': 'es-ab'},
#      {'id': 308,
#       'abbrev': 'A',
#       'name': 'Alicante',
#       'exception': None,
#       'iso': 'es-a'},
#      {'id': 309,
#       'abbrev': 'AL',
#       'name': 'Almería',
#       'exception': None,
#       'iso': 'es-al'},
#      {'id': 310,
#       'abbrev': 'O',
#       'name': 'Asturias',
#       'exception': None,
#       'iso': 'es-o'},
#      {'id': 311,
#       'abbrev': 'AV',
#       'name': 'Ávila',
#       'exception': None,
#       'iso': 'es-av'},
#      {'id': 312,
#       'abbrev': 'BA',
#       'name': 'Badajoz',
#       'exception': None,
#       'iso': 'es-ba'},
#      {'id': 313,
#       'abbrev': 'PM',
#       'name': 'Baleares',
#       'exception': None,
#       'iso': 'es-pm'},
#      {'id': 314,
#       'abbrev': 'B',
#       'name': 'Barcelona',
#       'exception': None,
#       'iso': 'es-b'},
#      {'id': 315,
#       'abbrev': 'BU',
#       'name': 'Burgos',
#       'exception': None,
#       'iso': 'es-bu'},
#      {'id': 316,
#       'abbrev': 'CC',
#       'name': 'Cáceres',
#       'exception': None,
#       'iso': 'es-cc'},
#      {'id': 317,
#       'abbrev': 'CA',
#       'name': 'Cádiz',
#       'exception': None,
#       'iso': 'es-ca'},
#      {'id': 318,
#       'abbrev': 'S',
#       'name': 'Cantabria',
#       'exception': None,
#       'iso': 'es-s'},
#      {'id': 319,
#       'abbrev': 'CS',
#       'name': 'Castellón',
#       'exception': None,
#       'iso': 'es-cs'},
#      {'id': 320,
#       'abbrev': 'CR',
#       'name': 'Ciudad Real',
#       'exception': None,
#       'iso': 'es-cr'},
#      {'id': 321,
#       'abbrev': 'CO',
#       'name': 'Córdoba',
#       'exception': None,
#       'iso': 'es-co'},
#      {'id': 322,
#       'abbrev': 'CU',
#       'name': 'Cuenca',
#       'exception': None,
#       'iso': 'es-cu'},
#      {'id': 323,
#       'abbrev': 'GI',
#       'name': 'Girona',
#       'exception': None,
#       'iso': 'es-gi'},
#      {'id': 324,
#       'abbrev': 'GR',
#       'name': 'Granada',
#       'exception': None,
#       'iso': 'es-gr'},
#      {'id': 325,
#       'abbrev': 'GU',
#       'name': 'Guadalajara',
#       'exception': None,
#       'iso': 'es-gu'},
#      {'id': 326,
#       'abbrev': 'SS',
#       'name': 'Guipúzcoa',
#       'exception': None,
#       'iso': 'es-ss'},
#      {'id': 327,
#       'abbrev': 'H',
#       'name': 'Huelva',
#       'exception': None,
#       'iso': 'es-h'},
#      {'id': 328,
#       'abbrev': 'HU',
#       'name': 'Huesca',
#       'exception': None,
#       'iso': 'es-hu'},
#      {'id': 329,
#       'abbrev': 'J',
#       'name': 'Jaén',
#       'exception': None,
#       'iso': 'es-j'},
#      {'id': 330,
#       'abbrev': 'C',
#       'name': 'A Coruña',
#       'exception': None,
#       'iso': 'es-c'},
#      {'id': 331,
#       'abbrev': 'LO',
#       'name': 'La Rioja',
#       'exception': None,
#       'iso': 'es-lo'},
#      {'id': 332,
#       'abbrev': 'GC',
#       'name': 'Las Palmas',
#       'exception': None,
#       'iso': 'es-gc'},
#      {'id': 333,
#       'abbrev': 'LE',
#       'name': 'León',
#       'exception': None,
#       'iso': 'es-le'},
#      {'id': 334,
#       'abbrev': 'L',
#       'name': 'Lleida',
#       'exception': None,
#       'iso': 'es-l'},
#      {'id': 335,
#       'abbrev': 'LU',
#       'name': 'Lugo',
#       'exception': None,
#       'iso': 'es-lu'},
#      {'id': 336,
#       'abbrev': 'M',
#       'name': 'Madrid',
#       'exception': None,
#       'iso': 'es-m'},
#      {'id': 337,
#       'abbrev': 'MA',
#       'name': 'Málaga',
#       'exception': None,
#       'iso': 'es-ma'},
#      {'id': 338,
#       'abbrev': 'MU',
#       'name': 'Murcia',
#       'exception': None,
#       'iso': 'es-mu'},
#      {'id': 339,
#       'abbrev': 'NA',
#       'name': 'Navarre',
#       'exception': None,
#       'iso': 'es-na'},
#      {'id': 340,
#       'abbrev': 'OR',
#       'name': 'Ourense',
#       'exception': None,
#       'iso': 'es-or'},
#      {'id': 341,
#       'abbrev': 'P',
#       'name': 'Palencia',
#       'exception': None,
#       'iso': 'es-p'},
#      {'id': 342,
#       'abbrev': 'PO',
#       'name': 'Pontevedra',
#       'exception': None,
#       'iso': 'es-po'},
#      {'id': 343,
#       'abbrev': 'SA',
#       'name': 'Salamanca',
#       'exception': None,
#       'iso': 'es-sa'},
#      {'id': 344,
#       'abbrev': 'TF',
#       'name': 'Santa Cruz De Tenerife',
#       'exception': None,
#       'iso': 'es-tf'},
#      {'id': 345,
#       'abbrev': 'SG',
#       'name': 'Segovia',
#       'exception': None,
#       'iso': 'es-sg'},
#      {'id': 346,
#       'abbrev': 'SE',
#       'name': 'Seville',
#       'exception': None,
#       'iso': 'es-se'},
#      {'id': 347,
#       'abbrev': 'SO',
#       'name': 'Soria',
#       'exception': None,
#       'iso': 'es-so'},
#      {'id': 348,
#       'abbrev': 'T',
#       'name': 'Tarragona',
#       'exception': None,
#       'iso': 'es-t'},
#      {'id': 349,
#       'abbrev': 'TE',
#       'name': 'Teruel',
#       'exception': None,
#       'iso': 'es-te'},
#      {'id': 350,
#       'abbrev': 'TO',
#       'name': 'Toledo',
#       'exception': None,
#       'iso': 'es-to'},
#      {'id': 351,
#       'abbrev': 'V',
#       'name': 'Valencia',
#       'exception': None,
#       'iso': 'es-v'},
#      {'id': 352,
#       'abbrev': 'VA',
#       'name': 'Valladolid',
#       'exception': None,
#       'iso': 'es-va'},
#      {'id': 353,
#       'abbrev': 'BI',
#       'name': 'Vizcaya',
#       'exception': None,
#       'iso': 'es-bi'},
#      {'id': 354,
#       'abbrev': 'ZA',
#       'name': 'Zamora',
#       'exception': None,
#       'iso': 'es-za'},
#      {'id': 355,
#       'abbrev': 'Z',
#       'name': 'Zaragoza',
#       'exception': None,
#       'iso': 'es-z'}]},
#    {'name': 'Day of Navarre',
#     'description': 'People celebrate the culture of the Navarre region in Spain and life of Saint Francis Xavier on the Day of Navarre. It is an annual local public holiday in this region on December 3.',
#     'date': {'iso': '2019-12-03',
#      'datetime': {'year': 2019, 'month': 12, 'day': 3}},
#     'type': ['Local holiday'],
#     'locations': 'NA',
#     'states': [{'id': 301,
#       'abbrev': 'NA',
#       'name': 'Navarre',
#       'exception': None,
#       'iso': 'es-nc'}]},
#    {'name': 'Constitution Day',
#     'description': 'Constitution Day marks the anniversary of the referendum to approve the Spanish Constitution and is a public holiday in Spain.',
#     'date': {'iso': '2019-12-06',
#      'datetime': {'year': 2019, 'month': 12, 'day': 6}},
#     'type': ['National holiday'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Immaculate Conception',
#     'description': 'The Feast of the Immaculate Conception is a Christian observance on December 8 each year.',
#     'date': {'iso': '2019-12-08',
#      'datetime': {'year': 2019, 'month': 12, 'day': 8}},
#     'type': ['National holiday'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Immaculate Conception observed',
#     'description': None,
#     'date': {'iso': '2019-12-09',
#      'datetime': {'year': 2019, 'month': 12, 'day': 9}},
#     'type': ['National holiday'],
#     'locations': 'AN, AR, O, S, CL, EX, M, LO, ML',
#     'states': [{'id': 212,
#       'abbrev': 'AN',
#       'name': 'Andalusia',
#       'exception': None,
#       'iso': 'es-an'},
#      {'id': 213,
#       'abbrev': 'AR',
#       'name': 'Aragon',
#       'exception': None,
#       'iso': 'es-ar'},
#      {'id': 288,
#       'abbrev': 'O',
#       'name': 'Asturias',
#       'exception': None,
#       'iso': 'es-as'},
#      {'id': 292,
#       'abbrev': 'S',
#       'name': 'Cantabria',
#       'exception': None,
#       'iso': 'es-cb'},
#      {'id': 294,
#       'abbrev': 'CL',
#       'name': 'Castile-Leon',
#       'exception': None,
#       'iso': 'es-cl'},
#      {'id': 296,
#       'abbrev': 'EX',
#       'name': 'Extremadura',
#       'exception': None,
#       'iso': 'es-ex'},
#      {'id': 299,
#       'abbrev': 'M',
#       'name': 'Madrid',
#       'exception': None,
#       'iso': 'es-md'},
#      {'id': 298,
#       'abbrev': 'LO',
#       'name': 'La Rioja',
#       'exception': None,
#       'iso': 'es-ri'},
#      {'id': 304,
#       'abbrev': 'ML',
#       'name': 'Melilla',
#       'exception': None,
#       'iso': 'es-ml'}]},
#    {'name': 'December Solstice',
#     'description': None,
#     'date': {'iso': '2019-12-22T05:19:26+01:00',
#      'datetime': {'year': 2019,
#       'month': 12,
#       'day': 22,
#       'hour': 5,
#       'minute': 19,
#       'second': 26},
#      'timezone': {'offset': '+01:00',
#       'zoneabb': 'CET',
#       'zoneoffset': 3600,
#       'zonedst': 0,
#       'zonetotaloffset': 3600}},
#     'type': ['Season'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Christmas Eve',
#     'description': 'Christmas Eve is the day before Christmas Day and falls on December 24 in the Gregorian calendar.',
#     'date': {'iso': '2019-12-24',
#      'datetime': {'year': 2019, 'month': 12, 'day': 24}},
#     'type': ['Observance'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Christmas Day',
#     'description': 'Christmas Day is one of the biggest Christian celebrations and falls on December 25 in the Gregorian calendar.',
#     'date': {'iso': '2019-12-25',
#      'datetime': {'year': 2019, 'month': 12, 'day': 25}},
#     'type': ['National holiday'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': "St Stephen's Day",
#     'description': 'The Feast of St Stephen is a holiday to commemorate the life and death of an early Christian saint.',
#     'date': {'iso': '2019-12-26',
#      'datetime': {'year': 2019, 'month': 12, 'day': 26}},
#     'type': ['Local holiday'],
#     'locations': 'IB, CT',
#     'states': [{'id': 289,
#       'abbrev': 'IB',
#       'name': 'Balearic Islands',
#       'exception': None,
#       'iso': 'es-ib'},
#      {'id': 295,
#       'abbrev': 'CT',
#       'name': 'Catalonia',
#       'exception': None,
#       'iso': 'es-ct'}]},
#    {'name': 'Feast of the Holy Family',
#     'description': None,
#     'date': {'iso': '2019-12-29',
#      'datetime': {'year': 2019, 'month': 12, 'day': 29}},
#     'type': ['Observance'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': "New Year's Eve",
#     'description': 'New Year’s Eve is the last day of the year, December 31, in the Gregorian calendar.',
#     'date': {'iso': '2019-12-31',
#      'datetime': {'year': 2019, 'month': 12, 'day': 31}},
#     'type': ['Observance'],
#     'locations': 'All',
#     'states': 'All'}]}}

# %%
res = res.json()['response']['holidays']
res
# Out:
# [{'name': "New Year's Day",
#   'description': 'New Year’s Day is the first day of the year, or January 1, in the Gregorian calendar.',
#   'date': {'iso': '2019-01-01',
#    'datetime': {'year': 2019, 'month': 1, 'day': 1}},
#   'type': ['National holiday'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Reconquest Day',
#   'description': None,
#   'date': {'iso': '2019-01-02',
#    'datetime': {'year': 2019, 'month': 1, 'day': 2}},
#   'type': ['Local holiday'],
#   'locations': 'GR',
#   'states': [{'id': 324,
#     'abbrev': 'GR',
#     'name': 'Granada',
#     'exception': None,
#     'iso': 'es-gr'}]},
#  {'name': 'Epiphany',
#   'description': 'Epiphany is a public holiday and the day most Christmas presentes are exchanged in Spain.',
#   'date': {'iso': '2019-01-06',
#    'datetime': {'year': 2019, 'month': 1, 'day': 6}},
#   'type': ['National holiday'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Epiphany observed',
#   'description': 'Epiphany observed on January 7 is a public holiday in most Spanish regions whenever January 6 is on a Sunday.',
#   'date': {'iso': '2019-01-07',
#    'datetime': {'year': 2019, 'month': 1, 'day': 7}},
#   'type': ['Common local holiday'],
#   'locations': 'AN, AR, O, CN, CL, EX, MU, NA, CE, M, ML',
#   'states': [{'id': 212,
#     'abbrev': 'AN',
#     'name': 'Andalusia',
#     'exception': None,
#     'iso': 'es-an'},
#    {'id': 213,
#     'abbrev': 'AR',
#     'name': 'Aragon',
#     'exception': None,
#     'iso': 'es-ar'},
#    {'id': 288,
#     'abbrev': 'O',
#     'name': 'Asturias',
#     'exception': None,
#     'iso': 'es-as'},
#    {'id': 291,
#     'abbrev': 'CN',
#     'name': 'Canary Islands',
#     'exception': None,
#     'iso': 'es-cn'},
#    {'id': 294,
#     'abbrev': 'CL',
#     'name': 'Castile-Leon',
#     'exception': None,
#     'iso': 'es-cl'},
#    {'id': 296,
#     'abbrev': 'EX',
#     'name': 'Extremadura',
#     'exception': None,
#     'iso': 'es-ex'},
#    {'id': 338,
#     'abbrev': 'MU',
#     'name': 'Murcia',
#     'exception': None,
#     'iso': 'es-mu'},
#    {'id': 339,
#     'abbrev': 'NA',
#     'name': 'Navarre',
#     'exception': None,
#     'iso': 'es-na'},
#    {'id': 303,
#     'abbrev': 'CE',
#     'name': 'Ceuta',
#     'exception': None,
#     'iso': 'es-ce'},
#    {'id': 299,
#     'abbrev': 'M',
#     'name': 'Madrid',
#     'exception': None,
#     'iso': 'es-md'},
#    {'id': 304,
#     'abbrev': 'ML',
#     'name': 'Melilla',
#     'exception': None,
#     'iso': 'es-ml'}]},
#  {'name': "St. Valero's Feast",
#   'description': None,
#   'date': {'iso': '2019-01-29',
#    'datetime': {'year': 2019, 'month': 1, 'day': 29}},
#   'type': ['Local holiday'],
#   'locations': 'Z',
#   'states': [{'id': 355,
#     'abbrev': 'Z',
#     'name': 'Zaragoza',
#     'exception': None,
#     'iso': 'es-z'}]},
#  {'name': "Valentine's Day",
#   'description': 'Valentine’s Day is a special time to celebrate love, romance and friendship.',
#   'date': {'iso': '2019-02-14',
#    'datetime': {'year': 2019, 'month': 2, 'day': 14}},
#   'type': ['Observance'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Day of Andalucía',
#   'description': 'The Day of Andalucía, also known as Andalucía Day, is an annual public holiday in the Andalucía autonomous community in Spain on February 28.',
#   'date': {'iso': '2019-02-28',
#    'datetime': {'year': 2019, 'month': 2, 'day': 28}},
#   'type': ['Local holiday'],
#   'locations': 'AN',
#   'states': [{'id': 212,
#     'abbrev': 'AN',
#     'name': 'Andalusia',
#     'exception': None,
#     'iso': 'es-an'}]},
#  {'name': 'Day of the Balearic Islands',
#   'description': "The Day of the Balearic Islands is held on March 1 to remember the date when the Balearic Islands' Statute of Autonomy came into effect. It is a local public holiday in this area in Spain.",
#   'date': {'iso': '2019-03-01',
#    'datetime': {'year': 2019, 'month': 3, 'day': 1}},
#   'type': ['Local holiday'],
#   'locations': 'IB',
#   'states': [{'id': 289,
#     'abbrev': 'IB',
#     'name': 'Balearic Islands',
#     'exception': None,
#     'iso': 'es-ib'}]},
#  {'name': 'Fifth of March',
#   'description': None,
#   'date': {'iso': '2019-03-05',
#    'datetime': {'year': 2019, 'month': 3, 'day': 5}},
#   'type': ['Local holiday'],
#   'locations': 'Z',
#   'states': [{'id': 355,
#     'abbrev': 'Z',
#     'name': 'Zaragoza',
#     'exception': None,
#     'iso': 'es-z'}]},
#  {'name': 'Ash Wednesday',
#   'description': 'Ash Wednesday marks the first day of Lent in western Christian churches.',
#   'date': {'iso': '2019-03-06',
#    'datetime': {'year': 2019, 'month': 3, 'day': 6}},
#   'type': ['Observance'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'San Jose',
#   'description': "Saint Joseph's Day honors St Joseph, the Virgin Mary's spouse. It is a public holiday in some parts of Spain on March 19 each year.",
#   'date': {'iso': '2019-03-19',
#    'datetime': {'year': 2019, 'month': 3, 'day': 19}},
#   'type': ['Common local holiday'],
#   'locations': 'VC, GA, MU, NA, PV',
#   'states': [{'id': 302,
#     'abbrev': 'VC',
#     'name': 'Valencia',
#     'exception': None,
#     'iso': 'es-vc'},
#    {'id': 297,
#     'abbrev': 'GA',
#     'name': 'Galicia',
#     'exception': None,
#     'iso': 'es-ga'},
#    {'id': 300,
#     'abbrev': 'MU',
#     'name': 'Murcia',
#     'exception': None,
#     'iso': 'es-mc'},
#    {'id': 301,
#     'abbrev': 'NA',
#     'name': 'Navarre',
#     'exception': None,
#     'iso': 'es-nc'},
#    {'id': 290,
#     'abbrev': 'PV',
#     'name': 'Basque Country',
#     'exception': None,
#     'iso': 'es-pv'}]},
#  {'name': 'March Equinox',
#   'description': None,
#   'date': {'iso': '2019-03-20T22:58:32+01:00',
#    'datetime': {'year': 2019,
#     'month': 3,
#     'day': 20,
#     'hour': 22,
#     'minute': 58,
#     'second': 32},
#    'timezone': {'offset': '+01:00',
#     'zoneabb': 'CET',
#     'zoneoffset': 3600,
#     'zonedst': 0,
#     'zonetotaloffset': 3600}},
#   'type': ['Season'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Daylight Saving Time starts',
#   'description': None,
#   'date': {'iso': '2019-03-31T02:00:00+01:00',
#    'datetime': {'year': 2019,
#     'month': 3,
#     'day': 31,
#     'hour': 2,
#     'minute': 0,
#     'second': 0},
#    'timezone': {'offset': '+01:00',
#     'zoneabb': 'CET',
#     'zoneoffset': 3600,
#     'zonedst': 0,
#     'zonetotaloffset': 3600}},
#   'type': ['Clock change/Daylight Saving Time'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Palm Sunday',
#   'description': 'Palm Sunday is a Christian feast that commemorates Jesus Christ’s entry into Jerusalem. It is also the start of Holy Week.',
#   'date': {'iso': '2019-04-14',
#    'datetime': {'year': 2019, 'month': 4, 'day': 14}},
#   'type': ['Observance'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Maundy Thursday',
#   'description': 'Maundy Thursday is a Christian observance on the Thursday during Holy Week. It is the day before Good Friday.',
#   'date': {'iso': '2019-04-18',
#    'datetime': {'year': 2019, 'month': 4, 'day': 18}},
#   'type': ['Common local holiday'],
#   'locations': '16 states',
#   'states': [{'id': 212,
#     'abbrev': 'AN',
#     'name': 'Andalusia',
#     'exception': None,
#     'iso': 'es-an'},
#    {'id': 213,
#     'abbrev': 'AR',
#     'name': 'Aragon',
#     'exception': None,
#     'iso': 'es-ar'},
#    {'id': 288,
#     'abbrev': 'O',
#     'name': 'Asturias',
#     'exception': None,
#     'iso': 'es-as'},
#    {'id': 289,
#     'abbrev': 'IB',
#     'name': 'Balearic Islands',
#     'exception': None,
#     'iso': 'es-ib'},
#    {'id': 290,
#     'abbrev': 'PV',
#     'name': 'Basque Country',
#     'exception': None,
#     'iso': 'es-pv'},
#    {'id': 291,
#     'abbrev': 'CN',
#     'name': 'Canary Islands',
#     'exception': None,
#     'iso': 'es-cn'},
#    {'id': 293,
#     'abbrev': 'CM',
#     'name': 'Castile-La Mancha',
#     'exception': None,
#     'iso': 'es-cm'},
#    {'id': 294,
#     'abbrev': 'CL',
#     'name': 'Castile-Leon',
#     'exception': None,
#     'iso': 'es-cl'},
#    {'id': 303,
#     'abbrev': 'CE',
#     'name': 'Ceuta',
#     'exception': None,
#     'iso': 'es-ce'},
#    {'id': 296,
#     'abbrev': 'EX',
#     'name': 'Extremadura',
#     'exception': None,
#     'iso': 'es-ex'},
#    {'id': 297,
#     'abbrev': 'GA',
#     'name': 'Galicia',
#     'exception': None,
#     'iso': 'es-ga'},
#    {'id': 299,
#     'abbrev': 'M',
#     'name': 'Madrid',
#     'exception': None,
#     'iso': 'es-md'},
#    {'id': 304,
#     'abbrev': 'ML',
#     'name': 'Melilla',
#     'exception': None,
#     'iso': 'es-ml'},
#    {'id': 300,
#     'abbrev': 'MU',
#     'name': 'Murcia',
#     'exception': None,
#     'iso': 'es-mc'},
#    {'id': 301,
#     'abbrev': 'NA',
#     'name': 'Navarre',
#     'exception': None,
#     'iso': 'es-nc'},
#    {'id': 298,
#     'abbrev': 'LO',
#     'name': 'La Rioja',
#     'exception': None,
#     'iso': 'es-ri'}]},
#  {'name': 'Good Friday',
#   'description': 'Good Friday is a global Christian observance two days before Easter Sunday.',
#   'date': {'iso': '2019-04-19',
#    'datetime': {'year': 2019, 'month': 4, 'day': 19}},
#   'type': ['National holiday'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Easter Sunday',
#   'description': 'Easter Sunday commemorates Jesus Christ’s resurrection, according to Christian belief.',
#   'date': {'iso': '2019-04-21',
#    'datetime': {'year': 2019, 'month': 4, 'day': 21}},
#   'type': ['Observance'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Easter Monday',
#   'description': 'Easter Monday is the day after Easter Sunday.',
#   'date': {'iso': '2019-04-22',
#    'datetime': {'year': 2019, 'month': 4, 'day': 22}},
#   'type': ['Common local holiday'],
#   'locations': 'IB, S, CM, CT, VC, NA, PV, LO',
#   'states': [{'id': 289,
#     'abbrev': 'IB',
#     'name': 'Balearic Islands',
#     'exception': None,
#     'iso': 'es-ib'},
#    {'id': 292,
#     'abbrev': 'S',
#     'name': 'Cantabria',
#     'exception': None,
#     'iso': 'es-cb'},
#    {'id': 293,
#     'abbrev': 'CM',
#     'name': 'Castile-La Mancha',
#     'exception': None,
#     'iso': 'es-cm'},
#    {'id': 295,
#     'abbrev': 'CT',
#     'name': 'Catalonia',
#     'exception': None,
#     'iso': 'es-ct'},
#    {'id': 302,
#     'abbrev': 'VC',
#     'name': 'Valencia',
#     'exception': None,
#     'iso': 'es-vc'},
#    {'id': 301,
#     'abbrev': 'NA',
#     'name': 'Navarre',
#     'exception': None,
#     'iso': 'es-nc'},
#    {'id': 290,
#     'abbrev': 'PV',
#     'name': 'Basque Country',
#     'exception': None,
#     'iso': 'es-pv'},
#    {'id': 298,
#     'abbrev': 'LO',
#     'name': 'La Rioja',
#     'exception': None,
#     'iso': 'es-ri'}]},
#  {'name': 'Day of Aragón',
#   'description': "The Day of Aragon celebrates the Spanish region of Aragon's culture and history. It is an annual local public holiday on April 23.",
#   'date': {'iso': '2019-04-23',
#    'datetime': {'year': 2019, 'month': 4, 'day': 23}},
#   'type': ['Local holiday'],
#   'locations': 'AR',
#   'states': [{'id': 213,
#     'abbrev': 'AR',
#     'name': 'Aragon',
#     'exception': None,
#     'iso': 'es-ar'}]},
#  {'name': "St George's Day",
#   'description': "St George's Day is an occasion for people in Catalonia to give loved ones a rose and a book.",
#   'date': {'iso': '2019-04-23',
#    'datetime': {'year': 2019, 'month': 4, 'day': 23}},
#   'type': ['Local observance'],
#   'locations': 'CT',
#   'states': [{'id': 295,
#     'abbrev': 'CT',
#     'name': 'Catalonia',
#     'exception': None,
#     'iso': 'es-ct'}]},
#  {'name': 'Castile and León Day',
#   'description': 'Castile and León Day is celebrated in the Spanish autonomous community of Castile and León on April 23 every year.',
#   'date': {'iso': '2019-04-23',
#    'datetime': {'year': 2019, 'month': 4, 'day': 23}},
#   'type': ['Local holiday'],
#   'locations': 'CL',
#   'states': [{'id': 294,
#     'abbrev': 'CL',
#     'name': 'Castile-Leon',
#     'exception': None,
#     'iso': 'es-cl'}]},
#  {'name': 'Labor Day / May Day',
#   'description': 'May Day, or Labor Day, is a day off for workers in many countries around the world.',
#   'date': {'iso': '2019-05-01',
#    'datetime': {'year': 2019, 'month': 5, 'day': 1}},
#   'type': ['National holiday'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Day of Madrid',
#   'description': 'The Day of the Autonomous Community of Madrid, Spain, marks the anniversary of an uprising against French troops in Madrid. It is an annual local public holiday on May 2.',
#   'date': {'iso': '2019-05-02',
#    'datetime': {'year': 2019, 'month': 5, 'day': 2}},
#   'type': ['Local holiday'],
#   'locations': 'M',
#   'states': [{'id': 299,
#     'abbrev': 'M',
#     'name': 'Madrid',
#     'exception': None,
#     'iso': 'es-md'}]},
#  {'name': "Mothers' Day",
#   'description': 'One of Spain’s most popular and festive family occasions is Mothers’ Day on the first Sunday in May.',
#   'date': {'iso': '2019-05-05',
#    'datetime': {'year': 2019, 'month': 5, 'day': 5}},
#   'type': ['Observance'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Feast Day of St Isidore',
#   'description': None,
#   'date': {'iso': '2019-05-15',
#    'datetime': {'year': 2019, 'month': 5, 'day': 15}},
#   'type': ['Local holiday'],
#   'locations': 'M',
#   'states': [{'id': 299,
#     'abbrev': 'M',
#     'name': 'Madrid',
#     'exception': None,
#     'iso': 'es-md'}]},
#  {'name': 'Galicia Literature Day',
#   'description': 'Galician Literature Day is a local public holiday annually celebrated in autonomous community of Galicia in Spain on May 17. It commemorates writers who wrote in the Galician language.',
#   'date': {'iso': '2019-05-17',
#    'datetime': {'year': 2019, 'month': 5, 'day': 17}},
#   'type': ['Local holiday'],
#   'locations': 'GA',
#   'states': [{'id': 297,
#     'abbrev': 'GA',
#     'name': 'Galicia',
#     'exception': None,
#     'iso': 'es-ga'}]},
#  {'name': 'Day of the Canary Islands',
#   'description': "The Day of the Canary Islands marks the anniversary of the autonomous Canary Islands Parliament's first session. It is a local public holiday on the Canary Islands on May 30 each year.",
#   'date': {'iso': '2019-05-30',
#    'datetime': {'year': 2019, 'month': 5, 'day': 30}},
#   'type': ['Local holiday'],
#   'locations': 'CN',
#   'states': [{'id': 291,
#     'abbrev': 'CN',
#     'name': 'Canary Islands',
#     'exception': None,
#     'iso': 'es-cn'}]},
#  {'name': 'Day of Castile-La Mancha',
#   'description': "The Day of the Region of Castilla-La Mancha marks the anniversary of when Castilla-La Mancha's first regional courts were opened. It is an annual public holiday in this Spanish region on May 31.",
#   'date': {'iso': '2019-05-31',
#    'datetime': {'year': 2019, 'month': 5, 'day': 31}},
#   'type': ['Local holiday'],
#   'locations': 'CM',
#   'states': [{'id': 293,
#     'abbrev': 'CM',
#     'name': 'Castile-La Mancha',
#     'exception': None,
#     'iso': 'es-cm'}]},
#  {'name': 'Whit Sunday/Pentecost',
#   'description': 'Many Christians all over the world annually observe Pentecost, also known as Whitsunday or Whit Sunday.',
#   'date': {'iso': '2019-06-09',
#    'datetime': {'year': 2019, 'month': 6, 'day': 9}},
#   'type': ['Observance'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Whit Monday',
#   'description': 'Whit Monday, or Pentecost Monday, is a Christian holiday that falls on the day after Pentecost, which is also known as Whit Sunday or Whitsunday.',
#   'date': {'iso': '2019-06-10',
#    'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#   'type': ['Local holiday'],
#   'locations': 'B',
#   'states': [{'id': 314,
#     'abbrev': 'B',
#     'name': 'Barcelona',
#     'exception': None,
#     'iso': 'es-b'}]},
#  {'name': 'Day of Murcia',
#   'description': "The Day of the Region of Murcia marks the anniversary of when the autonomy of Murcia's statutes was approved. It is an annual public holiday in Murcia, Spain, on June 9.",
#   'date': {'iso': '2019-06-10',
#    'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#   'type': ['Local holiday'],
#   'locations': 'MU',
#   'states': [{'id': 300,
#     'abbrev': 'MU',
#     'name': 'Murcia',
#     'exception': None,
#     'iso': 'es-mc'}]},
#  {'name': 'Day of Murcia observed',
#   'description': "The Day of the Region of Murcia marks the anniversary of when the autonomy of Murcia's statutes was approved. It is an annual public holiday in Murcia, Spain, on June 9.",
#   'date': {'iso': '2019-06-10',
#    'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#   'type': ['Local holiday'],
#   'locations': 'MU',
#   'states': [{'id': 300,
#     'abbrev': 'MU',
#     'name': 'Murcia',
#     'exception': None,
#     'iso': 'es-mc'}]},
#  {'name': 'Day of La Rioja',
#   'description': 'The Day of La Rioja is an annual public holiday in the Spanish autonomous community of La Rioja on June 9.',
#   'date': {'iso': '2019-06-10',
#    'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#   'type': ['Local holiday'],
#   'locations': 'LO',
#   'states': [{'id': 298,
#     'abbrev': 'LO',
#     'name': 'La Rioja',
#     'exception': None,
#     'iso': 'es-ri'}]},
#  {'name': 'Day of La Rioja observed',
#   'description': 'The Day of La Rioja is an annual public holiday in the Spanish autonomous community of La Rioja on June 9.',
#   'date': {'iso': '2019-06-10',
#    'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#   'type': ['Local holiday'],
#   'locations': 'LO',
#   'states': [{'id': 298,
#     'abbrev': 'LO',
#     'name': 'La Rioja',
#     'exception': None,
#     'iso': 'es-ri'}]},
#  {'name': 'San Antonio',
#   'description': "The Day of Saint Anthony of Padua marks the anniversary of St Anthony's death. It is a local public holiday in Ceuta, Spain, on June 13 each year.",
#   'date': {'iso': '2019-06-13',
#    'datetime': {'year': 2019, 'month': 6, 'day': 13}},
#   'type': ['Local holiday'],
#   'locations': 'CE',
#   'states': [{'id': 303,
#     'abbrev': 'CE',
#     'name': 'Ceuta',
#     'exception': None,
#     'iso': 'es-ce'}]},
#  {'name': 'Corpus Christi',
#   'description': 'Corpus Christi is a Christian feast in honor of the Holy Eucharist.',
#   'date': {'iso': '2019-06-20',
#    'datetime': {'year': 2019, 'month': 6, 'day': 20}},
#   'type': ['Local holiday'],
#   'locations': 'CM, GR',
#   'states': [{'id': 293,
#     'abbrev': 'CM',
#     'name': 'Castile-La Mancha',
#     'exception': None,
#     'iso': 'es-cm'},
#    {'id': 324,
#     'abbrev': 'GR',
#     'name': 'Granada',
#     'exception': None,
#     'iso': 'es-gr'}]},
#  {'name': 'June Solstice',
#   'description': None,
#   'date': {'iso': '2019-06-21T17:54:14+02:00',
#    'datetime': {'year': 2019,
#     'month': 6,
#     'day': 21,
#     'hour': 17,
#     'minute': 54,
#     'second': 14},
#    'timezone': {'offset': '+02:00',
#     'zoneabb': 'CEST',
#     'zoneoffset': 3600,
#     'zonedst': 3600,
#     'zonetotaloffset': 7200}},
#   'type': ['Season'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Saint John the Baptist Day',
#   'description': 'Saint John the Baptist Day is annually held on June 24 to honor the life of St John, an early Christian saint. It is a public holiday in Catalonia, Spain.',
#   'date': {'iso': '2019-06-24',
#    'datetime': {'year': 2019, 'month': 6, 'day': 24}},
#   'type': ['Local holiday'],
#   'locations': 'CT',
#   'states': [{'id': 295,
#     'abbrev': 'CT',
#     'name': 'Catalonia',
#     'exception': None,
#     'iso': 'es-ct'}]},
#  {'name': 'Feast of Saint James the Apostle',
#   'description': "Saint James' Day is an occasion to honor the life and deeds of one of Jesus' disciples. It is a public holiday in the autonomous communities of the Basque Country and Galicia in Spain on July 25.",
#   'date': {'iso': '2019-07-25',
#    'datetime': {'year': 2019, 'month': 7, 'day': 25}},
#   'type': ['Common local holiday'],
#   'locations': 'GA, S, PV',
#   'states': [{'id': 297,
#     'abbrev': 'GA',
#     'name': 'Galicia',
#     'exception': None,
#     'iso': 'es-ga'},
#    {'id': 292,
#     'abbrev': 'S',
#     'name': 'Cantabria',
#     'exception': None,
#     'iso': 'es-cb'},
#    {'id': 290,
#     'abbrev': 'PV',
#     'name': 'Basque Country',
#     'exception': None,
#     'iso': 'es-pv'}]},
#  {'name': 'The Day of Our Lady of Africa',
#   'description': 'The Day of Our Lady of Africa honors the patron saint of the city of Ceuta. It is a public holiday in this Spanish city on August 5.',
#   'date': {'iso': '2019-08-05',
#    'datetime': {'year': 2019, 'month': 8, 'day': 5}},
#   'type': ['Local holiday'],
#   'locations': 'CE',
#   'states': [{'id': 303,
#     'abbrev': 'CE',
#     'name': 'Ceuta',
#     'exception': None,
#     'iso': 'es-ce'}]},
#  {'name': 'The Day of Cantabria',
#   'description': 'The Day of Cantabria celebrates the history, culture and language of the Cantabrian region of Spain. It is annually held on the second Sunday of August.',
#   'date': {'iso': '2019-08-11',
#    'datetime': {'year': 2019, 'month': 8, 'day': 11}},
#   'type': ['Local observance'],
#   'locations': 'S',
#   'states': [{'id': 292,
#     'abbrev': 'S',
#     'name': 'Cantabria',
#     'exception': None,
#     'iso': 'es-cb'}]},
#  {'name': 'Eid al-Adha',
#   'description': 'Eid al-Adha (Id ul-Adha) is an Islamic festival falling on the 10th day of the month of Dhul Hijja (Thou al-Hijja) to commemorate the willingness of Ibrahim (Abraham) to sacrifice his son.',
#   'date': {'iso': '2019-08-12',
#    'datetime': {'year': 2019, 'month': 8, 'day': 12}},
#   'type': ['Local holiday'],
#   'locations': 'CE',
#   'states': [{'id': 303,
#     'abbrev': 'CE',
#     'name': 'Ceuta',
#     'exception': None,
#     'iso': 'es-ce'}]},
#  {'name': 'Eid al-Adha',
#   'description': 'Eid al-Adha (Id ul-Adha) is an Islamic festival falling on the 10th day of the month of Dhul Hijja (Thou al-Hijja) to commemorate the willingness of Ibrahim (Abraham) to sacrifice his son.',
#   'date': {'iso': '2019-08-12',
#    'datetime': {'year': 2019, 'month': 8, 'day': 12}},
#   'type': ['Local holiday'],
#   'locations': 'ML',
#   'states': [{'id': 304,
#     'abbrev': 'ML',
#     'name': 'Melilla',
#     'exception': None,
#     'iso': 'es-ml'}]},
#  {'name': 'Assumption of Mary',
#   'description': 'The Christian feast of the Assumption of Mary is on or around Aug 15 in most countries. A few celebrate Assumption Day at other times of the year.',
#   'date': {'iso': '2019-08-15',
#    'datetime': {'year': 2019, 'month': 8, 'day': 15}},
#   'type': ['National holiday'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Day of the Independent City of Ceuta',
#   'description': 'The Day of Ceuta is celebrated as a local public holiday in the city of Ceuta in Spain on September 2 each year. This date commemorates when Pedro de Menezes (Meneses) took control of Ceuta.',
#   'date': {'iso': '2019-09-02',
#    'datetime': {'year': 2019, 'month': 9, 'day': 2}},
#   'type': ['Local holiday'],
#   'locations': 'CE',
#   'states': [{'id': 303,
#     'abbrev': 'CE',
#     'name': 'Ceuta',
#     'exception': None,
#     'iso': 'es-ce'}]},
#  {'name': 'Day of Asturias',
#   'description': 'The Day of Asturias commemorates the Virgin of Covadonga and the Battle of Covadonga. It is an annual local public holiday in the autonomous community of Asturias in Spain on September 8.',
#   'date': {'iso': '2019-09-08',
#    'datetime': {'year': 2019, 'month': 9, 'day': 8}},
#   'type': ['Local holiday'],
#   'locations': 'O',
#   'states': [{'id': 288,
#     'abbrev': 'O',
#     'name': 'Asturias',
#     'exception': None,
#     'iso': 'es-as'}]},
#  {'name': 'Day of Extremadura',
#   'description': "The Day of Extremadura marks the anniversary of the Virgin Mary's birth. It is a local public holiday in Extremadura, Spain, on September 8.",
#   'date': {'iso': '2019-09-08',
#    'datetime': {'year': 2019, 'month': 9, 'day': 8}},
#   'type': ['Local holiday'],
#   'locations': 'EX',
#   'states': [{'id': 296,
#     'abbrev': 'EX',
#     'name': 'Extremadura',
#     'exception': None,
#     'iso': 'es-ex'}]},
#  {'name': 'Virgin of the Victory',
#   'description': None,
#   'date': {'iso': '2019-09-08',
#    'datetime': {'year': 2019, 'month': 9, 'day': 8}},
#   'type': ['Local holiday'],
#   'locations': 'ML',
#   'states': [{'id': 304,
#     'abbrev': 'ML',
#     'name': 'Melilla',
#     'exception': None,
#     'iso': 'es-ml'}]},
#  {'name': 'Day of Asturias observed',
#   'description': 'The Day of Asturias commemorates the Virgin of Covadonga and the Battle of Covadonga. It is an annual local public holiday in the autonomous community of Asturias in Spain on September 8.',
#   'date': {'iso': '2019-09-09',
#    'datetime': {'year': 2019, 'month': 9, 'day': 9}},
#   'type': ['Local holiday'],
#   'locations': 'O',
#   'states': [{'id': 288,
#     'abbrev': 'O',
#     'name': 'Asturias',
#     'exception': None,
#     'iso': 'es-as'}]},
#  {'name': 'Day of Extremadura observed',
#   'description': "The Day of Extremadura marks the anniversary of the Virgin Mary's birth. It is a local public holiday in Extremadura, Spain, on September 8.",
#   'date': {'iso': '2019-09-09',
#    'datetime': {'year': 2019, 'month': 9, 'day': 9}},
#   'type': ['Local holiday'],
#   'locations': 'EX',
#   'states': [{'id': 296,
#     'abbrev': 'EX',
#     'name': 'Extremadura',
#     'exception': None,
#     'iso': 'es-ex'}]},
#  {'name': 'Virgin of the Victory observed',
#   'description': None,
#   'date': {'iso': '2019-09-09',
#    'datetime': {'year': 2019, 'month': 9, 'day': 9}},
#   'type': ['Local holiday'],
#   'locations': 'ML',
#   'states': [{'id': 304,
#     'abbrev': 'ML',
#     'name': 'Melilla',
#     'exception': None,
#     'iso': 'es-ml'}]},
#  {'name': 'Day of Catalonia',
#   'description': 'The Day of Catalonia commemorates the end of the siege of Barcelona in 1714. It is a local public holiday in Barcelona, Spain, on September 11.',
#   'date': {'iso': '2019-09-11',
#    'datetime': {'year': 2019, 'month': 9, 'day': 11}},
#   'type': ['Local holiday'],
#   'locations': 'CT',
#   'states': [{'id': 295,
#     'abbrev': 'CT',
#     'name': 'Catalonia',
#     'exception': None,
#     'iso': 'es-ct'}]},
#  {'name': 'Nuestra Señora de la Bien Aparecida',
#   'description': None,
#   'date': {'iso': '2019-09-15',
#    'datetime': {'year': 2019, 'month': 9, 'day': 15}},
#   'type': ['Local holiday'],
#   'locations': 'S',
#   'states': [{'id': 292,
#     'abbrev': 'S',
#     'name': 'Cantabria',
#     'exception': None,
#     'iso': 'es-cb'}]},
#  {'name': 'Day of Melilla',
#   'description': 'The Day of Melilla marks the anniversary of the storming of the city in 1497 and is a public holiday in Melilla, Spain.',
#   'date': {'iso': '2019-09-17',
#    'datetime': {'year': 2019, 'month': 9, 'day': 17}},
#   'type': ['Local holiday'],
#   'locations': 'ML',
#   'states': [{'id': 304,
#     'abbrev': 'ML',
#     'name': 'Melilla',
#     'exception': None,
#     'iso': 'es-ml'}]},
#  {'name': 'September Equinox',
#   'description': None,
#   'date': {'iso': '2019-09-23T09:50:13+02:00',
#    'datetime': {'year': 2019,
#     'month': 9,
#     'day': 23,
#     'hour': 9,
#     'minute': 50,
#     'second': 13},
#    'timezone': {'offset': '+02:00',
#     'zoneabb': 'CEST',
#     'zoneoffset': 3600,
#     'zonedst': 3600,
#     'zonetotaloffset': 7200}},
#   'type': ['Season'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Day of the Valencian Community',
#   'description': 'The Day of the Valencian Community is a local public holiday in Valencia, Spain, on October 9 each year. It celebrates Valencian culture and history.',
#   'date': {'iso': '2019-10-09',
#    'datetime': {'year': 2019, 'month': 10, 'day': 9}},
#   'type': ['Local holiday'],
#   'locations': 'VC',
#   'states': [{'id': 302,
#     'abbrev': 'VC',
#     'name': 'Valencia',
#     'exception': None,
#     'iso': 'es-vc'}]},
#  {'name': 'Hispanic Day',
#   'description': 'Hispanic Day marks the anniversary of the date that Christopher Columbus first set foot in the Americas. It is a public holiday in Spain on October 12.',
#   'date': {'iso': '2019-10-12',
#    'datetime': {'year': 2019, 'month': 10, 'day': 12}},
#   'type': ['National holiday'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Daylight Saving Time ends',
#   'description': None,
#   'date': {'iso': '2019-10-27T03:00:00+02:00',
#    'datetime': {'year': 2019,
#     'month': 10,
#     'day': 27,
#     'hour': 3,
#     'minute': 0,
#     'second': 0},
#    'timezone': {'offset': '+02:00',
#     'zoneabb': 'CEST',
#     'zoneoffset': 3600,
#     'zonedst': 3600,
#     'zonetotaloffset': 7200}},
#   'type': ['Clock change/Daylight Saving Time'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': "All Saints' Day",
#   'description': "Many churches honor all their saints on All Saints' Day, also known as All Hallows' Day.",
#   'date': {'iso': '2019-11-01',
#    'datetime': {'year': 2019, 'month': 11, 'day': 1}},
#   'type': ['National holiday'],
#   'locations': 'CL, AN, AR, O, EX, CN, S, CE, M, ML',
#   'states': [{'id': 294,
#     'abbrev': 'CL',
#     'name': 'Castile-Leon',
#     'exception': None,
#     'iso': 'es-cl'},
#    {'id': 212,
#     'abbrev': 'AN',
#     'name': 'Andalusia',
#     'exception': None,
#     'iso': 'es-an'},
#    {'id': 213,
#     'abbrev': 'AR',
#     'name': 'Aragon',
#     'exception': None,
#     'iso': 'es-ar'},
#    {'id': 288,
#     'abbrev': 'O',
#     'name': 'Asturias',
#     'exception': None,
#     'iso': 'es-as'},
#    {'id': 296,
#     'abbrev': 'EX',
#     'name': 'Extremadura',
#     'exception': None,
#     'iso': 'es-ex'},
#    {'id': 291,
#     'abbrev': 'CN',
#     'name': 'Canary Islands',
#     'exception': None,
#     'iso': 'es-cn'},
#    {'id': 292,
#     'abbrev': 'S',
#     'name': 'Cantabria',
#     'exception': None,
#     'iso': 'es-cb'},
#    {'id': 303,
#     'abbrev': 'CE',
#     'name': 'Ceuta',
#     'exception': None,
#     'iso': 'es-ce'},
#    {'id': 299,
#     'abbrev': 'M',
#     'name': 'Madrid',
#     'exception': None,
#     'iso': 'es-md'},
#    {'id': 304,
#     'abbrev': 'ML',
#     'name': 'Melilla',
#     'exception': None,
#     'iso': 'es-ml'}]},
#  {'name': "All Saints' Day",
#   'description': "Many churches honor all their saints on All Saints' Day, also known as All Hallows' Day.",
#   'date': {'iso': '2019-11-01',
#    'datetime': {'year': 2019, 'month': 11, 'day': 1}},
#   'type': ['National holiday'],
#   'locations': 'All except AN, AR, O, CN, S, CL, EX, M, ML',
#   'states': [{'id': 289,
#     'abbrev': 'IB',
#     'name': 'Balearic Islands',
#     'exception': None,
#     'iso': 'es-ib'},
#    {'id': 290,
#     'abbrev': 'PV',
#     'name': 'Basque Country',
#     'exception': None,
#     'iso': 'es-pv'},
#    {'id': 293,
#     'abbrev': 'CM',
#     'name': 'Castile-La Mancha',
#     'exception': None,
#     'iso': 'es-cm'},
#    {'id': 295,
#     'abbrev': 'CT',
#     'name': 'Catalonia',
#     'exception': None,
#     'iso': 'es-ct'},
#    {'id': 297,
#     'abbrev': 'GA',
#     'name': 'Galicia',
#     'exception': None,
#     'iso': 'es-ga'},
#    {'id': 298,
#     'abbrev': 'LO',
#     'name': 'La Rioja',
#     'exception': None,
#     'iso': 'es-ri'},
#    {'id': 300,
#     'abbrev': 'MU',
#     'name': 'Murcia',
#     'exception': None,
#     'iso': 'es-mc'},
#    {'id': 301,
#     'abbrev': 'NA',
#     'name': 'Navarre',
#     'exception': None,
#     'iso': 'es-nc'},
#    {'id': 302,
#     'abbrev': 'VC',
#     'name': 'Valencia',
#     'exception': None,
#     'iso': 'es-vc'},
#    {'id': 303,
#     'abbrev': 'CE',
#     'name': 'Ceuta',
#     'exception': None,
#     'iso': 'es-ce'},
#    {'id': 306,
#     'abbrev': 'VI',
#     'name': 'Álava',
#     'exception': None,
#     'iso': 'es-vi'},
#    {'id': 307,
#     'abbrev': 'AB',
#     'name': 'Albacete',
#     'exception': None,
#     'iso': 'es-ab'},
#    {'id': 308,
#     'abbrev': 'A',
#     'name': 'Alicante',
#     'exception': None,
#     'iso': 'es-a'},
#    {'id': 309,
#     'abbrev': 'AL',
#     'name': 'Almería',
#     'exception': None,
#     'iso': 'es-al'},
#    {'id': 310,
#     'abbrev': 'O',
#     'name': 'Asturias',
#     'exception': None,
#     'iso': 'es-o'},
#    {'id': 311,
#     'abbrev': 'AV',
#     'name': 'Ávila',
#     'exception': None,
#     'iso': 'es-av'},
#    {'id': 312,
#     'abbrev': 'BA',
#     'name': 'Badajoz',
#     'exception': None,
#     'iso': 'es-ba'},
#    {'id': 313,
#     'abbrev': 'PM',
#     'name': 'Baleares',
#     'exception': None,
#     'iso': 'es-pm'},
#    {'id': 314,
#     'abbrev': 'B',
#     'name': 'Barcelona',
#     'exception': None,
#     'iso': 'es-b'},
#    {'id': 315,
#     'abbrev': 'BU',
#     'name': 'Burgos',
#     'exception': None,
#     'iso': 'es-bu'},
#    {'id': 316,
#     'abbrev': 'CC',
#     'name': 'Cáceres',
#     'exception': None,
#     'iso': 'es-cc'},
#    {'id': 317,
#     'abbrev': 'CA',
#     'name': 'Cádiz',
#     'exception': None,
#     'iso': 'es-ca'},
#    {'id': 318,
#     'abbrev': 'S',
#     'name': 'Cantabria',
#     'exception': None,
#     'iso': 'es-s'},
#    {'id': 319,
#     'abbrev': 'CS',
#     'name': 'Castellón',
#     'exception': None,
#     'iso': 'es-cs'},
#    {'id': 320,
#     'abbrev': 'CR',
#     'name': 'Ciudad Real',
#     'exception': None,
#     'iso': 'es-cr'},
#    {'id': 321,
#     'abbrev': 'CO',
#     'name': 'Córdoba',
#     'exception': None,
#     'iso': 'es-co'},
#    {'id': 322,
#     'abbrev': 'CU',
#     'name': 'Cuenca',
#     'exception': None,
#     'iso': 'es-cu'},
#    {'id': 323,
#     'abbrev': 'GI',
#     'name': 'Girona',
#     'exception': None,
#     'iso': 'es-gi'},
#    {'id': 324,
#     'abbrev': 'GR',
#     'name': 'Granada',
#     'exception': None,
#     'iso': 'es-gr'},
#    {'id': 325,
#     'abbrev': 'GU',
#     'name': 'Guadalajara',
#     'exception': None,
#     'iso': 'es-gu'},
#    {'id': 326,
#     'abbrev': 'SS',
#     'name': 'Guipúzcoa',
#     'exception': None,
#     'iso': 'es-ss'},
#    {'id': 327,
#     'abbrev': 'H',
#     'name': 'Huelva',
#     'exception': None,
#     'iso': 'es-h'},
#    {'id': 328,
#     'abbrev': 'HU',
#     'name': 'Huesca',
#     'exception': None,
#     'iso': 'es-hu'},
#    {'id': 329,
#     'abbrev': 'J',
#     'name': 'Jaén',
#     'exception': None,
#     'iso': 'es-j'},
#    {'id': 330,
#     'abbrev': 'C',
#     'name': 'A Coruña',
#     'exception': None,
#     'iso': 'es-c'},
#    {'id': 331,
#     'abbrev': 'LO',
#     'name': 'La Rioja',
#     'exception': None,
#     'iso': 'es-lo'},
#    {'id': 332,
#     'abbrev': 'GC',
#     'name': 'Las Palmas',
#     'exception': None,
#     'iso': 'es-gc'},
#    {'id': 333,
#     'abbrev': 'LE',
#     'name': 'León',
#     'exception': None,
#     'iso': 'es-le'},
#    {'id': 334,
#     'abbrev': 'L',
#     'name': 'Lleida',
#     'exception': None,
#     'iso': 'es-l'},
#    {'id': 335,
#     'abbrev': 'LU',
#     'name': 'Lugo',
#     'exception': None,
#     'iso': 'es-lu'},
#    {'id': 336,
#     'abbrev': 'M',
#     'name': 'Madrid',
#     'exception': None,
#     'iso': 'es-m'},
#    {'id': 337,
#     'abbrev': 'MA',
#     'name': 'Málaga',
#     'exception': None,
#     'iso': 'es-ma'},
#    {'id': 338,
#     'abbrev': 'MU',
#     'name': 'Murcia',
#     'exception': None,
#     'iso': 'es-mu'},
#    {'id': 339,
#     'abbrev': 'NA',
#     'name': 'Navarre',
#     'exception': None,
#     'iso': 'es-na'},
#    {'id': 340,
#     'abbrev': 'OR',
#     'name': 'Ourense',
#     'exception': None,
#     'iso': 'es-or'},
#    {'id': 341,
#     'abbrev': 'P',
#     'name': 'Palencia',
#     'exception': None,
#     'iso': 'es-p'},
#    {'id': 342,
#     'abbrev': 'PO',
#     'name': 'Pontevedra',
#     'exception': None,
#     'iso': 'es-po'},
#    {'id': 343,
#     'abbrev': 'SA',
#     'name': 'Salamanca',
#     'exception': None,
#     'iso': 'es-sa'},
#    {'id': 344,
#     'abbrev': 'TF',
#     'name': 'Santa Cruz De Tenerife',
#     'exception': None,
#     'iso': 'es-tf'},
#    {'id': 345,
#     'abbrev': 'SG',
#     'name': 'Segovia',
#     'exception': None,
#     'iso': 'es-sg'},
#    {'id': 346,
#     'abbrev': 'SE',
#     'name': 'Seville',
#     'exception': None,
#     'iso': 'es-se'},
#    {'id': 347,
#     'abbrev': 'SO',
#     'name': 'Soria',
#     'exception': None,
#     'iso': 'es-so'},
#    {'id': 348,
#     'abbrev': 'T',
#     'name': 'Tarragona',
#     'exception': None,
#     'iso': 'es-t'},
#    {'id': 349,
#     'abbrev': 'TE',
#     'name': 'Teruel',
#     'exception': None,
#     'iso': 'es-te'},
#    {'id': 350,
#     'abbrev': 'TO',
#     'name': 'Toledo',
#     'exception': None,
#     'iso': 'es-to'},
#    {'id': 351,
#     'abbrev': 'V',
#     'name': 'Valencia',
#     'exception': None,
#     'iso': 'es-v'},
#    {'id': 352,
#     'abbrev': 'VA',
#     'name': 'Valladolid',
#     'exception': None,
#     'iso': 'es-va'},
#    {'id': 353,
#     'abbrev': 'BI',
#     'name': 'Vizcaya',
#     'exception': None,
#     'iso': 'es-bi'},
#    {'id': 354,
#     'abbrev': 'ZA',
#     'name': 'Zamora',
#     'exception': None,
#     'iso': 'es-za'},
#    {'id': 355,
#     'abbrev': 'Z',
#     'name': 'Zaragoza',
#     'exception': None,
#     'iso': 'es-z'}]},
#  {'name': 'Day of Navarre',
#   'description': 'People celebrate the culture of the Navarre region in Spain and life of Saint Francis Xavier on the Day of Navarre. It is an annual local public holiday in this region on December 3.',
#   'date': {'iso': '2019-12-03',
#    'datetime': {'year': 2019, 'month': 12, 'day': 3}},
#   'type': ['Local holiday'],
#   'locations': 'NA',
#   'states': [{'id': 301,
#     'abbrev': 'NA',
#     'name': 'Navarre',
#     'exception': None,
#     'iso': 'es-nc'}]},
#  {'name': 'Constitution Day',
#   'description': 'Constitution Day marks the anniversary of the referendum to approve the Spanish Constitution and is a public holiday in Spain.',
#   'date': {'iso': '2019-12-06',
#    'datetime': {'year': 2019, 'month': 12, 'day': 6}},
#   'type': ['National holiday'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Immaculate Conception',
#   'description': 'The Feast of the Immaculate Conception is a Christian observance on December 8 each year.',
#   'date': {'iso': '2019-12-08',
#    'datetime': {'year': 2019, 'month': 12, 'day': 8}},
#   'type': ['National holiday'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Immaculate Conception observed',
#   'description': None,
#   'date': {'iso': '2019-12-09',
#    'datetime': {'year': 2019, 'month': 12, 'day': 9}},
#   'type': ['National holiday'],
#   'locations': 'AN, AR, O, S, CL, EX, M, LO, ML',
#   'states': [{'id': 212,
#     'abbrev': 'AN',
#     'name': 'Andalusia',
#     'exception': None,
#     'iso': 'es-an'},
#    {'id': 213,
#     'abbrev': 'AR',
#     'name': 'Aragon',
#     'exception': None,
#     'iso': 'es-ar'},
#    {'id': 288,
#     'abbrev': 'O',
#     'name': 'Asturias',
#     'exception': None,
#     'iso': 'es-as'},
#    {'id': 292,
#     'abbrev': 'S',
#     'name': 'Cantabria',
#     'exception': None,
#     'iso': 'es-cb'},
#    {'id': 294,
#     'abbrev': 'CL',
#     'name': 'Castile-Leon',
#     'exception': None,
#     'iso': 'es-cl'},
#    {'id': 296,
#     'abbrev': 'EX',
#     'name': 'Extremadura',
#     'exception': None,
#     'iso': 'es-ex'},
#    {'id': 299,
#     'abbrev': 'M',
#     'name': 'Madrid',
#     'exception': None,
#     'iso': 'es-md'},
#    {'id': 298,
#     'abbrev': 'LO',
#     'name': 'La Rioja',
#     'exception': None,
#     'iso': 'es-ri'},
#    {'id': 304,
#     'abbrev': 'ML',
#     'name': 'Melilla',
#     'exception': None,
#     'iso': 'es-ml'}]},
#  {'name': 'December Solstice',
#   'description': None,
#   'date': {'iso': '2019-12-22T05:19:26+01:00',
#    'datetime': {'year': 2019,
#     'month': 12,
#     'day': 22,
#     'hour': 5,
#     'minute': 19,
#     'second': 26},
#    'timezone': {'offset': '+01:00',
#     'zoneabb': 'CET',
#     'zoneoffset': 3600,
#     'zonedst': 0,
#     'zonetotaloffset': 3600}},
#   'type': ['Season'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Christmas Eve',
#   'description': 'Christmas Eve is the day before Christmas Day and falls on December 24 in the Gregorian calendar.',
#   'date': {'iso': '2019-12-24',
#    'datetime': {'year': 2019, 'month': 12, 'day': 24}},
#   'type': ['Observance'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': 'Christmas Day',
#   'description': 'Christmas Day is one of the biggest Christian celebrations and falls on December 25 in the Gregorian calendar.',
#   'date': {'iso': '2019-12-25',
#    'datetime': {'year': 2019, 'month': 12, 'day': 25}},
#   'type': ['National holiday'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': "St Stephen's Day",
#   'description': 'The Feast of St Stephen is a holiday to commemorate the life and death of an early Christian saint.',
#   'date': {'iso': '2019-12-26',
#    'datetime': {'year': 2019, 'month': 12, 'day': 26}},
#   'type': ['Local holiday'],
#   'locations': 'IB, CT',
#   'states': [{'id': 289,
#     'abbrev': 'IB',
#     'name': 'Balearic Islands',
#     'exception': None,
#     'iso': 'es-ib'},
#    {'id': 295,
#     'abbrev': 'CT',
#     'name': 'Catalonia',
#     'exception': None,
#     'iso': 'es-ct'}]},
#  {'name': 'Feast of the Holy Family',
#   'description': None,
#   'date': {'iso': '2019-12-29',
#    'datetime': {'year': 2019, 'month': 12, 'day': 29}},
#   'type': ['Observance'],
#   'locations': 'All',
#   'states': 'All'},
#  {'name': "New Year's Eve",
#   'description': 'New Year’s Eve is the last day of the year, December 31, in the Gregorian calendar.',
#   'date': {'iso': '2019-12-31',
#    'datetime': {'year': 2019, 'month': 12, 'day': 31}},
#   'type': ['Observance'],
#   'locations': 'All',
#   'states': 'All'}]

# %%
res = pd.DataFrame(res)
res
# Out:
#                                                  date  \
# 0   {'iso': '2019-01-01', 'datetime': {'year': 201...
# 1   {'iso': '2019-01-02', 'datetime': {'year': 201...
# 2   {'iso': '2019-01-06', 'datetime': {'year': 201...
# 3   {'iso': '2019-01-07', 'datetime': {'year': 201...
# 4   {'iso': '2019-01-29', 'datetime': {'year': 201...
# 5   {'iso': '2019-02-14', 'datetime': {'year': 201...
# 6   {'iso': '2019-02-28', 'datetime': {'year': 201...
# 7   {'iso': '2019-03-01', 'datetime': {'year': 201...
# 8   {'iso': '2019-03-05', 'datetime': {'year': 201...
# 9   {'iso': '2019-03-06', 'datetime': {'year': 201...
# 10  {'iso': '2019-03-19', 'datetime': {'year': 201...
# 11  {'iso': '2019-03-20T22:58:32+01:00', 'datetime...
# 12  {'iso': '2019-03-31T02:00:00+01:00', 'datetime...
# 13  {'iso': '2019-04-14', 'datetime': {'year': 201...
# 14  {'iso': '2019-04-18', 'datetime': {'year': 201...
# 15  {'iso': '2019-04-19', 'datetime': {'year': 201...
# 16  {'iso': '2019-04-21', 'datetime': {'year': 201...
# 17  {'iso': '2019-04-22', 'datetime': {'year': 201...
# 18  {'iso': '2019-04-23', 'datetime': {'year': 201...
# 19  {'iso': '2019-04-23', 'datetime': {'year': 201...
# 20  {'iso': '2019-04-23', 'datetime': {'year': 201...
# 21  {'iso': '2019-05-01', 'datetime': {'year': 201...
# 22  {'iso': '2019-05-02', 'datetime': {'year': 201...
# 23  {'iso': '2019-05-05', 'datetime': {'year': 201...
# 24  {'iso': '2019-05-15', 'datetime': {'year': 201...
# 25  {'iso': '2019-05-17', 'datetime': {'year': 201...
# 26  {'iso': '2019-05-30', 'datetime': {'year': 201...
# 27  {'iso': '2019-05-31', 'datetime': {'year': 201...
# 28  {'iso': '2019-06-09', 'datetime': {'year': 201...
# 29  {'iso': '2019-06-10', 'datetime': {'year': 201...
# ..                                                ...
# 40  {'iso': '2019-08-11', 'datetime': {'year': 201...
# 41  {'iso': '2019-08-12', 'datetime': {'year': 201...
# 42  {'iso': '2019-08-12', 'datetime': {'year': 201...
# 43  {'iso': '2019-08-15', 'datetime': {'year': 201...
# 44  {'iso': '2019-09-02', 'datetime': {'year': 201...
# 45  {'iso': '2019-09-08', 'datetime': {'year': 201...
# 46  {'iso': '2019-09-08', 'datetime': {'year': 201...
# 47  {'iso': '2019-09-08', 'datetime': {'year': 201...
# 48  {'iso': '2019-09-09', 'datetime': {'year': 201...
# 49  {'iso': '2019-09-09', 'datetime': {'year': 201...
# 50  {'iso': '2019-09-09', 'datetime': {'year': 201...
# 51  {'iso': '2019-09-11', 'datetime': {'year': 201...
# 52  {'iso': '2019-09-15', 'datetime': {'year': 201...
# 53  {'iso': '2019-09-17', 'datetime': {'year': 201...
# 54  {'iso': '2019-09-23T09:50:13+02:00', 'datetime...
# 55  {'iso': '2019-10-09', 'datetime': {'year': 201...
# 56  {'iso': '2019-10-12', 'datetime': {'year': 201...
# 57  {'iso': '2019-10-27T03:00:00+02:00', 'datetime...
# 58  {'iso': '2019-11-01', 'datetime': {'year': 201...
# 59  {'iso': '2019-11-01', 'datetime': {'year': 201...
# 60  {'iso': '2019-12-03', 'datetime': {'year': 201...
# 61  {'iso': '2019-12-06', 'datetime': {'year': 201...
# 62  {'iso': '2019-12-08', 'datetime': {'year': 201...
# 63  {'iso': '2019-12-09', 'datetime': {'year': 201...
# 64  {'iso': '2019-12-22T05:19:26+01:00', 'datetime...
# 65  {'iso': '2019-12-24', 'datetime': {'year': 201...
# 66  {'iso': '2019-12-25', 'datetime': {'year': 201...
# 67  {'iso': '2019-12-26', 'datetime': {'year': 201...
# 68  {'iso': '2019-12-29', 'datetime': {'year': 201...
# 69  {'iso': '2019-12-31', 'datetime': {'year': 201...
#
#                                           description  \
# 0   New Year’s Day is the first day of the year, o...
# 1                                                None
# 2   Epiphany is a public holiday and the day most ...
# 3   Epiphany observed on January 7 is a public hol...
# 4                                                None
# 5   Valentine’s Day is a special time to celebrate...
# 6   The Day of Andalucía, also known as Andalucía ...
# 7   The Day of the Balearic Islands is held on Mar...
# 8                                                None
# 9   Ash Wednesday marks the first day of Lent in w...
# 10  Saint Joseph's Day honors St Joseph, the Virgi...
# 11                                               None
# 12                                               None
# 13  Palm Sunday is a Christian feast that commemor...
# 14  Maundy Thursday is a Christian observance on t...
# 15  Good Friday is a global Christian observance t...
# 16  Easter Sunday commemorates Jesus Christ’s resu...
# 17      Easter Monday is the day after Easter Sunday.
# 18  The Day of Aragon celebrates the Spanish regio...
# 19  St George's Day is an occasion for people in C...
# 20  Castile and León Day is celebrated in the Span...
# 21  May Day, or Labor Day, is a day off for worker...
# 22  The Day of the Autonomous Community of Madrid,...
# 23  One of Spain’s most popular and festive family...
# 24                                               None
# 25  Galician Literature Day is a local public holi...
# 26  The Day of the Canary Islands marks the annive...
# 27  The Day of the Region of Castilla-La Mancha ma...
# 28  Many Christians all over the world annually ob...
# 29  Whit Monday, or Pentecost Monday, is a Christi...
# ..                                                ...
# 40  The Day of Cantabria celebrates the history, c...
# 41  Eid al-Adha (Id ul-Adha) is an Islamic festiva...
# 42  Eid al-Adha (Id ul-Adha) is an Islamic festiva...
# 43  The Christian feast of the Assumption of Mary ...
# 44  The Day of Ceuta is celebrated as a local publ...
# 45  The Day of Asturias commemorates the Virgin of...
# 46  The Day of Extremadura marks the anniversary o...
# 47                                               None
# 48  The Day of Asturias commemorates the Virgin of...
# 49  The Day of Extremadura marks the anniversary o...
# 50                                               None
# 51  The Day of Catalonia commemorates the end of t...
# 52                                               None
# 53  The Day of Melilla marks the anniversary of th...
# 54                                               None
# 55  The Day of the Valencian Community is a local ...
# 56  Hispanic Day marks the anniversary of the date...
# 57                                               None
# 58  Many churches honor all their saints on All Sa...
# 59  Many churches honor all their saints on All Sa...
# 60  People celebrate the culture of the Navarre re...
# 61  Constitution Day marks the anniversary of the ...
# 62  The Feast of the Immaculate Conception is a Ch...
# 63                                               None
# 64                                               None
# 65  Christmas Eve is the day before Christmas Day ...
# 66  Christmas Day is one of the biggest Christian ...
# 67  The Feast of St Stephen is a holiday to commem...
# 68                                               None
# 69  New Year’s Eve is the last day of the year, De...
#
#                                      locations  \
# 0                                          All
# 1                                           GR
# 2                                          All
# 3     AN, AR, O, CN, CL, EX, MU, NA, CE, M, ML
# 4                                            Z
# 5                                          All
# 6                                           AN
# 7                                           IB
# 8                                            Z
# 9                                          All
# 10                          VC, GA, MU, NA, PV
# 11                                         All
# 12                                         All
# 13                                         All
# 14                                   16 states
# 15                                         All
# 16                                         All
# 17               IB, S, CM, CT, VC, NA, PV, LO
# 18                                          AR
# 19                                          CT
# 20                                          CL
# 21                                         All
# 22                                           M
# 23                                         All
# 24                                           M
# 25                                          GA
# 26                                          CN
# 27                                          CM
# 28                                         All
# 29                                           B
# ..                                         ...
# 40                                           S
# 41                                          CE
# 42                                          ML
# 43                                         All
# 44                                          CE
# 45                                           O
# 46                                          EX
# 47                                          ML
# 48                                           O
# 49                                          EX
# 50                                          ML
# 51                                          CT
# 52                                           S
# 53                                          ML
# 54                                         All
# 55                                          VC
# 56                                         All
# 57                                         All
# 58         CL, AN, AR, O, EX, CN, S, CE, M, ML
# 59  All except AN, AR, O, CN, S, CL, EX, M, ML
# 60                                          NA
# 61                                         All
# 62                                         All
# 63             AN, AR, O, S, CL, EX, M, LO, ML
# 64                                         All
# 65                                         All
# 66                                         All
# 67                                      IB, CT
# 68                                         All
# 69                                         All
#
#                                     name  \
# 0                         New Year's Day
# 1                         Reconquest Day
# 2                               Epiphany
# 3                      Epiphany observed
# 4                     St. Valero's Feast
# 5                        Valentine's Day
# 6                       Day of Andalucía
# 7            Day of the Balearic Islands
# 8                         Fifth of March
# 9                          Ash Wednesday
# 10                              San Jose
# 11                         March Equinox
# 12           Daylight Saving Time starts
# 13                           Palm Sunday
# 14                       Maundy Thursday
# 15                           Good Friday
# 16                         Easter Sunday
# 17                         Easter Monday
# 18                         Day of Aragón
# 19                       St George's Day
# 20                  Castile and León Day
# 21                   Labor Day / May Day
# 22                         Day of Madrid
# 23                          Mothers' Day
# 24               Feast Day of St Isidore
# 25                Galicia Literature Day
# 26             Day of the Canary Islands
# 27              Day of Castile-La Mancha
# 28                 Whit Sunday/Pentecost
# 29                           Whit Monday
# ..                                   ...
# 40                  The Day of Cantabria
# 41                           Eid al-Adha
# 42                           Eid al-Adha
# 43                    Assumption of Mary
# 44  Day of the Independent City of Ceuta
# 45                       Day of Asturias
# 46                    Day of Extremadura
# 47                 Virgin of the Victory
# 48              Day of Asturias observed
# 49           Day of Extremadura observed
# 50        Virgin of the Victory observed
# 51                      Day of Catalonia
# 52   Nuestra Señora de la Bien Aparecida
# 53                        Day of Melilla
# 54                     September Equinox
# 55        Day of the Valencian Community
# 56                          Hispanic Day
# 57             Daylight Saving Time ends
# 58                       All Saints' Day
# 59                       All Saints' Day
# 60                        Day of Navarre
# 61                      Constitution Day
# 62                 Immaculate Conception
# 63        Immaculate Conception observed
# 64                     December Solstice
# 65                         Christmas Eve
# 66                         Christmas Day
# 67                      St Stephen's Day
# 68              Feast of the Holy Family
# 69                        New Year's Eve
#
#                                                states  \
# 0                                                 All
# 1   [{'id': 324, 'abbrev': 'GR', 'name': 'Granada'...
# 2                                                 All
# 3   [{'id': 212, 'abbrev': 'AN', 'name': 'Andalusi...
# 4   [{'id': 355, 'abbrev': 'Z', 'name': 'Zaragoza'...
# 5                                                 All
# 6   [{'id': 212, 'abbrev': 'AN', 'name': 'Andalusi...
# 7   [{'id': 289, 'abbrev': 'IB', 'name': 'Balearic...
# 8   [{'id': 355, 'abbrev': 'Z', 'name': 'Zaragoza'...
# 9                                                 All
# 10  [{'id': 302, 'abbrev': 'VC', 'name': 'Valencia...
# 11                                                All
# 12                                                All
# 13                                                All
# 14  [{'id': 212, 'abbrev': 'AN', 'name': 'Andalusi...
# 15                                                All
# 16                                                All
# 17  [{'id': 289, 'abbrev': 'IB', 'name': 'Balearic...
# 18  [{'id': 213, 'abbrev': 'AR', 'name': 'Aragon',...
# 19  [{'id': 295, 'abbrev': 'CT', 'name': 'Cataloni...
# 20  [{'id': 294, 'abbrev': 'CL', 'name': 'Castile-...
# 21                                                All
# 22  [{'id': 299, 'abbrev': 'M', 'name': 'Madrid', ...
# 23                                                All
# 24  [{'id': 299, 'abbrev': 'M', 'name': 'Madrid', ...
# 25  [{'id': 297, 'abbrev': 'GA', 'name': 'Galicia'...
# 26  [{'id': 291, 'abbrev': 'CN', 'name': 'Canary I...
# 27  [{'id': 293, 'abbrev': 'CM', 'name': 'Castile-...
# 28                                                All
# 29  [{'id': 314, 'abbrev': 'B', 'name': 'Barcelona...
# ..                                                ...
# 40  [{'id': 292, 'abbrev': 'S', 'name': 'Cantabria...
# 41  [{'id': 303, 'abbrev': 'CE', 'name': 'Ceuta', ...
# 42  [{'id': 304, 'abbrev': 'ML', 'name': 'Melilla'...
# 43                                                All
# 44  [{'id': 303, 'abbrev': 'CE', 'name': 'Ceuta', ...
# 45  [{'id': 288, 'abbrev': 'O', 'name': 'Asturias'...
# 46  [{'id': 296, 'abbrev': 'EX', 'name': 'Extremad...
# 47  [{'id': 304, 'abbrev': 'ML', 'name': 'Melilla'...
# 48  [{'id': 288, 'abbrev': 'O', 'name': 'Asturias'...
# 49  [{'id': 296, 'abbrev': 'EX', 'name': 'Extremad...
# 50  [{'id': 304, 'abbrev': 'ML', 'name': 'Melilla'...
# 51  [{'id': 295, 'abbrev': 'CT', 'name': 'Cataloni...
# 52  [{'id': 292, 'abbrev': 'S', 'name': 'Cantabria...
# 53  [{'id': 304, 'abbrev': 'ML', 'name': 'Melilla'...
# 54                                                All
# 55  [{'id': 302, 'abbrev': 'VC', 'name': 'Valencia...
# 56                                                All
# 57                                                All
# 58  [{'id': 294, 'abbrev': 'CL', 'name': 'Castile-...
# 59  [{'id': 289, 'abbrev': 'IB', 'name': 'Balearic...
# 60  [{'id': 301, 'abbrev': 'NA', 'name': 'Navarre'...
# 61                                                All
# 62                                                All
# 63  [{'id': 212, 'abbrev': 'AN', 'name': 'Andalusi...
# 64                                                All
# 65                                                All
# 66                                                All
# 67  [{'id': 289, 'abbrev': 'IB', 'name': 'Balearic...
# 68                                                All
# 69                                                All
#
#                                    type
# 0                    [National holiday]
# 1                       [Local holiday]
# 2                    [National holiday]
# 3                [Common local holiday]
# 4                       [Local holiday]
# 5                          [Observance]
# 6                       [Local holiday]
# 7                       [Local holiday]
# 8                       [Local holiday]
# 9                          [Observance]
# 10               [Common local holiday]
# 11                             [Season]
# 12  [Clock change/Daylight Saving Time]
# 13                         [Observance]
# 14               [Common local holiday]
# 15                   [National holiday]
# 16                         [Observance]
# 17               [Common local holiday]
# 18                      [Local holiday]
# 19                   [Local observance]
# 20                      [Local holiday]
# 21                   [National holiday]
# 22                      [Local holiday]
# 23                         [Observance]
# 24                      [Local holiday]
# 25                      [Local holiday]
# 26                      [Local holiday]
# 27                      [Local holiday]
# 28                         [Observance]
# 29                      [Local holiday]
# ..                                  ...
# 40                   [Local observance]
# 41                      [Local holiday]
# 42                      [Local holiday]
# 43                   [National holiday]
# 44                      [Local holiday]
# 45                      [Local holiday]
# 46                      [Local holiday]
# 47                      [Local holiday]
# 48                      [Local holiday]
# 49                      [Local holiday]
# 50                      [Local holiday]
# 51                      [Local holiday]
# 52                      [Local holiday]
# 53                      [Local holiday]
# 54                             [Season]
# 55                      [Local holiday]
# 56                   [National holiday]
# 57  [Clock change/Daylight Saving Time]
# 58                   [National holiday]
# 59                   [National holiday]
# 60                      [Local holiday]
# 61                   [National holiday]
# 62                   [National holiday]
# 63                   [National holiday]
# 64                             [Season]
# 65                         [Observance]
# 66                   [National holiday]
# 67                      [Local holiday]
# 68                         [Observance]
# 69                         [Observance]
#
# [70 rows x 6 columns]

# %%
res.columns
# Out:
# Index(['date', 'description', 'locations', 'name', 'states', 'type'], dtype='object')

# %%
res = 
res = res.sort_values(by='name', ascending=False)
res = res.drop_duplicates(subset=['date', 'description', 'locations', 'name', 'states', 'type']).dropna()
return res

#def data_embellish(crash):
 #      crash.rename(columns={'date':'Date'}, inplace=True)
  #     crash.rename(columns={'operator':'Operator'}, inplace=True)
   #    crash.rename(columns={'location':'Location'}, inplace=True)
    #   return crash
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-20ca22090106> in <module>
# ----> 1 res = res.sort_values(by='name', ascending=False)
#       2 res = res.drop_duplicates(subset=['date', 'description', 'locations', 'name', 'states', 'type']).dropna()
#       3 return res
#       4
#       5 #def data_embellish(crash):
#
# AttributeError: 'list' object has no attribute 'sort_values'

# %%
lista = []
for item in :
    res = res.json()['response']['holidays'][item]
    lista.append(item)
    print(lista)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-eb6984089ef5> in <module>
#       1 lista = []
# ----> 2 for item in Index:
#       3     res = res.json()['response']['holidays'][item]
#       4     lista.append(item)
#       5     print(lista)
#
# NameError: name 'Index' is not defined

# %%
pd.DataFrame(res.json())
# Out:
#            meta                                           response
# code      200.0                                                NaN
# holidays    NaN  [{'name': 'New Year's Day', 'description': 'Ne...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9b939bb98baf> in <module>
# ----> 1 pd.DataFrame(res.json())['response']['holidays'][item]
#
# TypeError: list indices must be integers or slices, not str

# %%
BASE_URL = "https://calendarific.com/api/v2"
API_KEY = ''
with open("token_crash.py") as file: # Use file to refer to the file object
    API_KEY = file.read().strip()
country= 'ES'
year= '2019'
res = requests.get("{}/holidays?&api_key={}&country={}&year={}".format(BASE_URL,API_KEY,country,year))
#res.json()
#res['datetime'] = res.index

#lista=[]
#for item in res.json():
    res.json()['response']['holidays'][0]
    lista.append(item)
    print(lista)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-dc82f4004de8> in <module>
#      11 lista=[]
#      12 for item in res.json():
# ---> 13     res.json()['response']['holidays'][item]
#      14     lista.append(item)
#      15     print(lista)
#
# TypeError: list indices must be integers or slices, not str

# %%
res.json()['response']
#['holidays'][0]
# Out:
# {'holidays': [{'name': "New Year's Day",
#    'description': 'New Year’s Day is the first day of the year, or January 1, in the Gregorian calendar.',
#    'date': {'iso': '2019-01-01',
#     'datetime': {'year': 2019, 'month': 1, 'day': 1}},
#    'type': ['National holiday'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Reconquest Day',
#    'description': None,
#    'date': {'iso': '2019-01-02',
#     'datetime': {'year': 2019, 'month': 1, 'day': 2}},
#    'type': ['Local holiday'],
#    'locations': 'GR',
#    'states': [{'id': 324,
#      'abbrev': 'GR',
#      'name': 'Granada',
#      'exception': None,
#      'iso': 'es-gr'}]},
#   {'name': 'Epiphany',
#    'description': 'Epiphany is a public holiday and the day most Christmas presentes are exchanged in Spain.',
#    'date': {'iso': '2019-01-06',
#     'datetime': {'year': 2019, 'month': 1, 'day': 6}},
#    'type': ['National holiday'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Epiphany observed',
#    'description': 'Epiphany observed on January 7 is a public holiday in most Spanish regions whenever January 6 is on a Sunday.',
#    'date': {'iso': '2019-01-07',
#     'datetime': {'year': 2019, 'month': 1, 'day': 7}},
#    'type': ['Common local holiday'],
#    'locations': 'AN, AR, O, CN, CL, EX, MU, NA, CE, M, ML',
#    'states': [{'id': 212,
#      'abbrev': 'AN',
#      'name': 'Andalusia',
#      'exception': None,
#      'iso': 'es-an'},
#     {'id': 213,
#      'abbrev': 'AR',
#      'name': 'Aragon',
#      'exception': None,
#      'iso': 'es-ar'},
#     {'id': 288,
#      'abbrev': 'O',
#      'name': 'Asturias',
#      'exception': None,
#      'iso': 'es-as'},
#     {'id': 291,
#      'abbrev': 'CN',
#      'name': 'Canary Islands',
#      'exception': None,
#      'iso': 'es-cn'},
#     {'id': 294,
#      'abbrev': 'CL',
#      'name': 'Castile-Leon',
#      'exception': None,
#      'iso': 'es-cl'},
#     {'id': 296,
#      'abbrev': 'EX',
#      'name': 'Extremadura',
#      'exception': None,
#      'iso': 'es-ex'},
#     {'id': 338,
#      'abbrev': 'MU',
#      'name': 'Murcia',
#      'exception': None,
#      'iso': 'es-mu'},
#     {'id': 339,
#      'abbrev': 'NA',
#      'name': 'Navarre',
#      'exception': None,
#      'iso': 'es-na'},
#     {'id': 303,
#      'abbrev': 'CE',
#      'name': 'Ceuta',
#      'exception': None,
#      'iso': 'es-ce'},
#     {'id': 299,
#      'abbrev': 'M',
#      'name': 'Madrid',
#      'exception': None,
#      'iso': 'es-md'},
#     {'id': 304,
#      'abbrev': 'ML',
#      'name': 'Melilla',
#      'exception': None,
#      'iso': 'es-ml'}]},
#   {'name': "St. Valero's Feast",
#    'description': None,
#    'date': {'iso': '2019-01-29',
#     'datetime': {'year': 2019, 'month': 1, 'day': 29}},
#    'type': ['Local holiday'],
#    'locations': 'Z',
#    'states': [{'id': 355,
#      'abbrev': 'Z',
#      'name': 'Zaragoza',
#      'exception': None,
#      'iso': 'es-z'}]},
#   {'name': "Valentine's Day",
#    'description': 'Valentine’s Day is a special time to celebrate love, romance and friendship.',
#    'date': {'iso': '2019-02-14',
#     'datetime': {'year': 2019, 'month': 2, 'day': 14}},
#    'type': ['Observance'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Day of Andalucía',
#    'description': 'The Day of Andalucía, also known as Andalucía Day, is an annual public holiday in the Andalucía autonomous community in Spain on February 28.',
#    'date': {'iso': '2019-02-28',
#     'datetime': {'year': 2019, 'month': 2, 'day': 28}},
#    'type': ['Local holiday'],
#    'locations': 'AN',
#    'states': [{'id': 212,
#      'abbrev': 'AN',
#      'name': 'Andalusia',
#      'exception': None,
#      'iso': 'es-an'}]},
#   {'name': 'Day of the Balearic Islands',
#    'description': "The Day of the Balearic Islands is held on March 1 to remember the date when the Balearic Islands' Statute of Autonomy came into effect. It is a local public holiday in this area in Spain.",
#    'date': {'iso': '2019-03-01',
#     'datetime': {'year': 2019, 'month': 3, 'day': 1}},
#    'type': ['Local holiday'],
#    'locations': 'IB',
#    'states': [{'id': 289,
#      'abbrev': 'IB',
#      'name': 'Balearic Islands',
#      'exception': None,
#      'iso': 'es-ib'}]},
#   {'name': 'Fifth of March',
#    'description': None,
#    'date': {'iso': '2019-03-05',
#     'datetime': {'year': 2019, 'month': 3, 'day': 5}},
#    'type': ['Local holiday'],
#    'locations': 'Z',
#    'states': [{'id': 355,
#      'abbrev': 'Z',
#      'name': 'Zaragoza',
#      'exception': None,
#      'iso': 'es-z'}]},
#   {'name': 'Ash Wednesday',
#    'description': 'Ash Wednesday marks the first day of Lent in western Christian churches.',
#    'date': {'iso': '2019-03-06',
#     'datetime': {'year': 2019, 'month': 3, 'day': 6}},
#    'type': ['Observance'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'San Jose',
#    'description': "Saint Joseph's Day honors St Joseph, the Virgin Mary's spouse. It is a public holiday in some parts of Spain on March 19 each year.",
#    'date': {'iso': '2019-03-19',
#     'datetime': {'year': 2019, 'month': 3, 'day': 19}},
#    'type': ['Common local holiday'],
#    'locations': 'VC, GA, MU, NA, PV',
#    'states': [{'id': 302,
#      'abbrev': 'VC',
#      'name': 'Valencia',
#      'exception': None,
#      'iso': 'es-vc'},
#     {'id': 297,
#      'abbrev': 'GA',
#      'name': 'Galicia',
#      'exception': None,
#      'iso': 'es-ga'},
#     {'id': 300,
#      'abbrev': 'MU',
#      'name': 'Murcia',
#      'exception': None,
#      'iso': 'es-mc'},
#     {'id': 301,
#      'abbrev': 'NA',
#      'name': 'Navarre',
#      'exception': None,
#      'iso': 'es-nc'},
#     {'id': 290,
#      'abbrev': 'PV',
#      'name': 'Basque Country',
#      'exception': None,
#      'iso': 'es-pv'}]},
#   {'name': 'March Equinox',
#    'description': None,
#    'date': {'iso': '2019-03-20T22:58:32+01:00',
#     'datetime': {'year': 2019,
#      'month': 3,
#      'day': 20,
#      'hour': 22,
#      'minute': 58,
#      'second': 32},
#     'timezone': {'offset': '+01:00',
#      'zoneabb': 'CET',
#      'zoneoffset': 3600,
#      'zonedst': 0,
#      'zonetotaloffset': 3600}},
#    'type': ['Season'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Daylight Saving Time starts',
#    'description': None,
#    'date': {'iso': '2019-03-31T02:00:00+01:00',
#     'datetime': {'year': 2019,
#      'month': 3,
#      'day': 31,
#      'hour': 2,
#      'minute': 0,
#      'second': 0},
#     'timezone': {'offset': '+01:00',
#      'zoneabb': 'CET',
#      'zoneoffset': 3600,
#      'zonedst': 0,
#      'zonetotaloffset': 3600}},
#    'type': ['Clock change/Daylight Saving Time'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Palm Sunday',
#    'description': 'Palm Sunday is a Christian feast that commemorates Jesus Christ’s entry into Jerusalem. It is also the start of Holy Week.',
#    'date': {'iso': '2019-04-14',
#     'datetime': {'year': 2019, 'month': 4, 'day': 14}},
#    'type': ['Observance'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Maundy Thursday',
#    'description': 'Maundy Thursday is a Christian observance on the Thursday during Holy Week. It is the day before Good Friday.',
#    'date': {'iso': '2019-04-18',
#     'datetime': {'year': 2019, 'month': 4, 'day': 18}},
#    'type': ['Common local holiday'],
#    'locations': '16 states',
#    'states': [{'id': 212,
#      'abbrev': 'AN',
#      'name': 'Andalusia',
#      'exception': None,
#      'iso': 'es-an'},
#     {'id': 213,
#      'abbrev': 'AR',
#      'name': 'Aragon',
#      'exception': None,
#      'iso': 'es-ar'},
#     {'id': 288,
#      'abbrev': 'O',
#      'name': 'Asturias',
#      'exception': None,
#      'iso': 'es-as'},
#     {'id': 289,
#      'abbrev': 'IB',
#      'name': 'Balearic Islands',
#      'exception': None,
#      'iso': 'es-ib'},
#     {'id': 290,
#      'abbrev': 'PV',
#      'name': 'Basque Country',
#      'exception': None,
#      'iso': 'es-pv'},
#     {'id': 291,
#      'abbrev': 'CN',
#      'name': 'Canary Islands',
#      'exception': None,
#      'iso': 'es-cn'},
#     {'id': 293,
#      'abbrev': 'CM',
#      'name': 'Castile-La Mancha',
#      'exception': None,
#      'iso': 'es-cm'},
#     {'id': 294,
#      'abbrev': 'CL',
#      'name': 'Castile-Leon',
#      'exception': None,
#      'iso': 'es-cl'},
#     {'id': 303,
#      'abbrev': 'CE',
#      'name': 'Ceuta',
#      'exception': None,
#      'iso': 'es-ce'},
#     {'id': 296,
#      'abbrev': 'EX',
#      'name': 'Extremadura',
#      'exception': None,
#      'iso': 'es-ex'},
#     {'id': 297,
#      'abbrev': 'GA',
#      'name': 'Galicia',
#      'exception': None,
#      'iso': 'es-ga'},
#     {'id': 299,
#      'abbrev': 'M',
#      'name': 'Madrid',
#      'exception': None,
#      'iso': 'es-md'},
#     {'id': 304,
#      'abbrev': 'ML',
#      'name': 'Melilla',
#      'exception': None,
#      'iso': 'es-ml'},
#     {'id': 300,
#      'abbrev': 'MU',
#      'name': 'Murcia',
#      'exception': None,
#      'iso': 'es-mc'},
#     {'id': 301,
#      'abbrev': 'NA',
#      'name': 'Navarre',
#      'exception': None,
#      'iso': 'es-nc'},
#     {'id': 298,
#      'abbrev': 'LO',
#      'name': 'La Rioja',
#      'exception': None,
#      'iso': 'es-ri'}]},
#   {'name': 'Good Friday',
#    'description': 'Good Friday is a global Christian observance two days before Easter Sunday.',
#    'date': {'iso': '2019-04-19',
#     'datetime': {'year': 2019, 'month': 4, 'day': 19}},
#    'type': ['National holiday'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Easter Sunday',
#    'description': 'Easter Sunday commemorates Jesus Christ’s resurrection, according to Christian belief.',
#    'date': {'iso': '2019-04-21',
#     'datetime': {'year': 2019, 'month': 4, 'day': 21}},
#    'type': ['Observance'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Easter Monday',
#    'description': 'Easter Monday is the day after Easter Sunday.',
#    'date': {'iso': '2019-04-22',
#     'datetime': {'year': 2019, 'month': 4, 'day': 22}},
#    'type': ['Common local holiday'],
#    'locations': 'IB, S, CM, CT, VC, NA, PV, LO',
#    'states': [{'id': 289,
#      'abbrev': 'IB',
#      'name': 'Balearic Islands',
#      'exception': None,
#      'iso': 'es-ib'},
#     {'id': 292,
#      'abbrev': 'S',
#      'name': 'Cantabria',
#      'exception': None,
#      'iso': 'es-cb'},
#     {'id': 293,
#      'abbrev': 'CM',
#      'name': 'Castile-La Mancha',
#      'exception': None,
#      'iso': 'es-cm'},
#     {'id': 295,
#      'abbrev': 'CT',
#      'name': 'Catalonia',
#      'exception': None,
#      'iso': 'es-ct'},
#     {'id': 302,
#      'abbrev': 'VC',
#      'name': 'Valencia',
#      'exception': None,
#      'iso': 'es-vc'},
#     {'id': 301,
#      'abbrev': 'NA',
#      'name': 'Navarre',
#      'exception': None,
#      'iso': 'es-nc'},
#     {'id': 290,
#      'abbrev': 'PV',
#      'name': 'Basque Country',
#      'exception': None,
#      'iso': 'es-pv'},
#     {'id': 298,
#      'abbrev': 'LO',
#      'name': 'La Rioja',
#      'exception': None,
#      'iso': 'es-ri'}]},
#   {'name': 'Day of Aragón',
#    'description': "The Day of Aragon celebrates the Spanish region of Aragon's culture and history. It is an annual local public holiday on April 23.",
#    'date': {'iso': '2019-04-23',
#     'datetime': {'year': 2019, 'month': 4, 'day': 23}},
#    'type': ['Local holiday'],
#    'locations': 'AR',
#    'states': [{'id': 213,
#      'abbrev': 'AR',
#      'name': 'Aragon',
#      'exception': None,
#      'iso': 'es-ar'}]},
#   {'name': "St George's Day",
#    'description': "St George's Day is an occasion for people in Catalonia to give loved ones a rose and a book.",
#    'date': {'iso': '2019-04-23',
#     'datetime': {'year': 2019, 'month': 4, 'day': 23}},
#    'type': ['Local observance'],
#    'locations': 'CT',
#    'states': [{'id': 295,
#      'abbrev': 'CT',
#      'name': 'Catalonia',
#      'exception': None,
#      'iso': 'es-ct'}]},
#   {'name': 'Castile and León Day',
#    'description': 'Castile and León Day is celebrated in the Spanish autonomous community of Castile and León on April 23 every year.',
#    'date': {'iso': '2019-04-23',
#     'datetime': {'year': 2019, 'month': 4, 'day': 23}},
#    'type': ['Local holiday'],
#    'locations': 'CL',
#    'states': [{'id': 294,
#      'abbrev': 'CL',
#      'name': 'Castile-Leon',
#      'exception': None,
#      'iso': 'es-cl'}]},
#   {'name': 'Labor Day / May Day',
#    'description': 'May Day, or Labor Day, is a day off for workers in many countries around the world.',
#    'date': {'iso': '2019-05-01',
#     'datetime': {'year': 2019, 'month': 5, 'day': 1}},
#    'type': ['National holiday'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Day of Madrid',
#    'description': 'The Day of the Autonomous Community of Madrid, Spain, marks the anniversary of an uprising against French troops in Madrid. It is an annual local public holiday on May 2.',
#    'date': {'iso': '2019-05-02',
#     'datetime': {'year': 2019, 'month': 5, 'day': 2}},
#    'type': ['Local holiday'],
#    'locations': 'M',
#    'states': [{'id': 299,
#      'abbrev': 'M',
#      'name': 'Madrid',
#      'exception': None,
#      'iso': 'es-md'}]},
#   {'name': "Mothers' Day",
#    'description': 'One of Spain’s most popular and festive family occasions is Mothers’ Day on the first Sunday in May.',
#    'date': {'iso': '2019-05-05',
#     'datetime': {'year': 2019, 'month': 5, 'day': 5}},
#    'type': ['Observance'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Feast Day of St Isidore',
#    'description': None,
#    'date': {'iso': '2019-05-15',
#     'datetime': {'year': 2019, 'month': 5, 'day': 15}},
#    'type': ['Local holiday'],
#    'locations': 'M',
#    'states': [{'id': 299,
#      'abbrev': 'M',
#      'name': 'Madrid',
#      'exception': None,
#      'iso': 'es-md'}]},
#   {'name': 'Galicia Literature Day',
#    'description': 'Galician Literature Day is a local public holiday annually celebrated in autonomous community of Galicia in Spain on May 17. It commemorates writers who wrote in the Galician language.',
#    'date': {'iso': '2019-05-17',
#     'datetime': {'year': 2019, 'month': 5, 'day': 17}},
#    'type': ['Local holiday'],
#    'locations': 'GA',
#    'states': [{'id': 297,
#      'abbrev': 'GA',
#      'name': 'Galicia',
#      'exception': None,
#      'iso': 'es-ga'}]},
#   {'name': 'Day of the Canary Islands',
#    'description': "The Day of the Canary Islands marks the anniversary of the autonomous Canary Islands Parliament's first session. It is a local public holiday on the Canary Islands on May 30 each year.",
#    'date': {'iso': '2019-05-30',
#     'datetime': {'year': 2019, 'month': 5, 'day': 30}},
#    'type': ['Local holiday'],
#    'locations': 'CN',
#    'states': [{'id': 291,
#      'abbrev': 'CN',
#      'name': 'Canary Islands',
#      'exception': None,
#      'iso': 'es-cn'}]},
#   {'name': 'Day of Castile-La Mancha',
#    'description': "The Day of the Region of Castilla-La Mancha marks the anniversary of when Castilla-La Mancha's first regional courts were opened. It is an annual public holiday in this Spanish region on May 31.",
#    'date': {'iso': '2019-05-31',
#     'datetime': {'year': 2019, 'month': 5, 'day': 31}},
#    'type': ['Local holiday'],
#    'locations': 'CM',
#    'states': [{'id': 293,
#      'abbrev': 'CM',
#      'name': 'Castile-La Mancha',
#      'exception': None,
#      'iso': 'es-cm'}]},
#   {'name': 'Whit Sunday/Pentecost',
#    'description': 'Many Christians all over the world annually observe Pentecost, also known as Whitsunday or Whit Sunday.',
#    'date': {'iso': '2019-06-09',
#     'datetime': {'year': 2019, 'month': 6, 'day': 9}},
#    'type': ['Observance'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Whit Monday',
#    'description': 'Whit Monday, or Pentecost Monday, is a Christian holiday that falls on the day after Pentecost, which is also known as Whit Sunday or Whitsunday.',
#    'date': {'iso': '2019-06-10',
#     'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#    'type': ['Local holiday'],
#    'locations': 'B',
#    'states': [{'id': 314,
#      'abbrev': 'B',
#      'name': 'Barcelona',
#      'exception': None,
#      'iso': 'es-b'}]},
#   {'name': 'Day of Murcia',
#    'description': "The Day of the Region of Murcia marks the anniversary of when the autonomy of Murcia's statutes was approved. It is an annual public holiday in Murcia, Spain, on June 9.",
#    'date': {'iso': '2019-06-10',
#     'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#    'type': ['Local holiday'],
#    'locations': 'MU',
#    'states': [{'id': 300,
#      'abbrev': 'MU',
#      'name': 'Murcia',
#      'exception': None,
#      'iso': 'es-mc'}]},
#   {'name': 'Day of Murcia observed',
#    'description': "The Day of the Region of Murcia marks the anniversary of when the autonomy of Murcia's statutes was approved. It is an annual public holiday in Murcia, Spain, on June 9.",
#    'date': {'iso': '2019-06-10',
#     'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#    'type': ['Local holiday'],
#    'locations': 'MU',
#    'states': [{'id': 300,
#      'abbrev': 'MU',
#      'name': 'Murcia',
#      'exception': None,
#      'iso': 'es-mc'}]},
#   {'name': 'Day of La Rioja',
#    'description': 'The Day of La Rioja is an annual public holiday in the Spanish autonomous community of La Rioja on June 9.',
#    'date': {'iso': '2019-06-10',
#     'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#    'type': ['Local holiday'],
#    'locations': 'LO',
#    'states': [{'id': 298,
#      'abbrev': 'LO',
#      'name': 'La Rioja',
#      'exception': None,
#      'iso': 'es-ri'}]},
#   {'name': 'Day of La Rioja observed',
#    'description': 'The Day of La Rioja is an annual public holiday in the Spanish autonomous community of La Rioja on June 9.',
#    'date': {'iso': '2019-06-10',
#     'datetime': {'year': 2019, 'month': 6, 'day': 10}},
#    'type': ['Local holiday'],
#    'locations': 'LO',
#    'states': [{'id': 298,
#      'abbrev': 'LO',
#      'name': 'La Rioja',
#      'exception': None,
#      'iso': 'es-ri'}]},
#   {'name': 'San Antonio',
#    'description': "The Day of Saint Anthony of Padua marks the anniversary of St Anthony's death. It is a local public holiday in Ceuta, Spain, on June 13 each year.",
#    'date': {'iso': '2019-06-13',
#     'datetime': {'year': 2019, 'month': 6, 'day': 13}},
#    'type': ['Local holiday'],
#    'locations': 'CE',
#    'states': [{'id': 303,
#      'abbrev': 'CE',
#      'name': 'Ceuta',
#      'exception': None,
#      'iso': 'es-ce'}]},
#   {'name': 'Corpus Christi',
#    'description': 'Corpus Christi is a Christian feast in honor of the Holy Eucharist.',
#    'date': {'iso': '2019-06-20',
#     'datetime': {'year': 2019, 'month': 6, 'day': 20}},
#    'type': ['Local holiday'],
#    'locations': 'CM, GR',
#    'states': [{'id': 293,
#      'abbrev': 'CM',
#      'name': 'Castile-La Mancha',
#      'exception': None,
#      'iso': 'es-cm'},
#     {'id': 324,
#      'abbrev': 'GR',
#      'name': 'Granada',
#      'exception': None,
#      'iso': 'es-gr'}]},
#   {'name': 'June Solstice',
#    'description': None,
#    'date': {'iso': '2019-06-21T17:54:14+02:00',
#     'datetime': {'year': 2019,
#      'month': 6,
#      'day': 21,
#      'hour': 17,
#      'minute': 54,
#      'second': 14},
#     'timezone': {'offset': '+02:00',
#      'zoneabb': 'CEST',
#      'zoneoffset': 3600,
#      'zonedst': 3600,
#      'zonetotaloffset': 7200}},
#    'type': ['Season'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Saint John the Baptist Day',
#    'description': 'Saint John the Baptist Day is annually held on June 24 to honor the life of St John, an early Christian saint. It is a public holiday in Catalonia, Spain.',
#    'date': {'iso': '2019-06-24',
#     'datetime': {'year': 2019, 'month': 6, 'day': 24}},
#    'type': ['Local holiday'],
#    'locations': 'CT',
#    'states': [{'id': 295,
#      'abbrev': 'CT',
#      'name': 'Catalonia',
#      'exception': None,
#      'iso': 'es-ct'}]},
#   {'name': 'Feast of Saint James the Apostle',
#    'description': "Saint James' Day is an occasion to honor the life and deeds of one of Jesus' disciples. It is a public holiday in the autonomous communities of the Basque Country and Galicia in Spain on July 25.",
#    'date': {'iso': '2019-07-25',
#     'datetime': {'year': 2019, 'month': 7, 'day': 25}},
#    'type': ['Common local holiday'],
#    'locations': 'GA, S, PV',
#    'states': [{'id': 297,
#      'abbrev': 'GA',
#      'name': 'Galicia',
#      'exception': None,
#      'iso': 'es-ga'},
#     {'id': 292,
#      'abbrev': 'S',
#      'name': 'Cantabria',
#      'exception': None,
#      'iso': 'es-cb'},
#     {'id': 290,
#      'abbrev': 'PV',
#      'name': 'Basque Country',
#      'exception': None,
#      'iso': 'es-pv'}]},
#   {'name': 'The Day of Our Lady of Africa',
#    'description': 'The Day of Our Lady of Africa honors the patron saint of the city of Ceuta. It is a public holiday in this Spanish city on August 5.',
#    'date': {'iso': '2019-08-05',
#     'datetime': {'year': 2019, 'month': 8, 'day': 5}},
#    'type': ['Local holiday'],
#    'locations': 'CE',
#    'states': [{'id': 303,
#      'abbrev': 'CE',
#      'name': 'Ceuta',
#      'exception': None,
#      'iso': 'es-ce'}]},
#   {'name': 'The Day of Cantabria',
#    'description': 'The Day of Cantabria celebrates the history, culture and language of the Cantabrian region of Spain. It is annually held on the second Sunday of August.',
#    'date': {'iso': '2019-08-11',
#     'datetime': {'year': 2019, 'month': 8, 'day': 11}},
#    'type': ['Local observance'],
#    'locations': 'S',
#    'states': [{'id': 292,
#      'abbrev': 'S',
#      'name': 'Cantabria',
#      'exception': None,
#      'iso': 'es-cb'}]},
#   {'name': 'Eid al-Adha',
#    'description': 'Eid al-Adha (Id ul-Adha) is an Islamic festival falling on the 10th day of the month of Dhul Hijja (Thou al-Hijja) to commemorate the willingness of Ibrahim (Abraham) to sacrifice his son.',
#    'date': {'iso': '2019-08-12',
#     'datetime': {'year': 2019, 'month': 8, 'day': 12}},
#    'type': ['Local holiday'],
#    'locations': 'CE',
#    'states': [{'id': 303,
#      'abbrev': 'CE',
#      'name': 'Ceuta',
#      'exception': None,
#      'iso': 'es-ce'}]},
#   {'name': 'Eid al-Adha',
#    'description': 'Eid al-Adha (Id ul-Adha) is an Islamic festival falling on the 10th day of the month of Dhul Hijja (Thou al-Hijja) to commemorate the willingness of Ibrahim (Abraham) to sacrifice his son.',
#    'date': {'iso': '2019-08-12',
#     'datetime': {'year': 2019, 'month': 8, 'day': 12}},
#    'type': ['Local holiday'],
#    'locations': 'ML',
#    'states': [{'id': 304,
#      'abbrev': 'ML',
#      'name': 'Melilla',
#      'exception': None,
#      'iso': 'es-ml'}]},
#   {'name': 'Assumption of Mary',
#    'description': 'The Christian feast of the Assumption of Mary is on or around Aug 15 in most countries. A few celebrate Assumption Day at other times of the year.',
#    'date': {'iso': '2019-08-15',
#     'datetime': {'year': 2019, 'month': 8, 'day': 15}},
#    'type': ['National holiday'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Day of the Independent City of Ceuta',
#    'description': 'The Day of Ceuta is celebrated as a local public holiday in the city of Ceuta in Spain on September 2 each year. This date commemorates when Pedro de Menezes (Meneses) took control of Ceuta.',
#    'date': {'iso': '2019-09-02',
#     'datetime': {'year': 2019, 'month': 9, 'day': 2}},
#    'type': ['Local holiday'],
#    'locations': 'CE',
#    'states': [{'id': 303,
#      'abbrev': 'CE',
#      'name': 'Ceuta',
#      'exception': None,
#      'iso': 'es-ce'}]},
#   {'name': 'Day of Asturias',
#    'description': 'The Day of Asturias commemorates the Virgin of Covadonga and the Battle of Covadonga. It is an annual local public holiday in the autonomous community of Asturias in Spain on September 8.',
#    'date': {'iso': '2019-09-08',
#     'datetime': {'year': 2019, 'month': 9, 'day': 8}},
#    'type': ['Local holiday'],
#    'locations': 'O',
#    'states': [{'id': 288,
#      'abbrev': 'O',
#      'name': 'Asturias',
#      'exception': None,
#      'iso': 'es-as'}]},
#   {'name': 'Day of Extremadura',
#    'description': "The Day of Extremadura marks the anniversary of the Virgin Mary's birth. It is a local public holiday in Extremadura, Spain, on September 8.",
#    'date': {'iso': '2019-09-08',
#     'datetime': {'year': 2019, 'month': 9, 'day': 8}},
#    'type': ['Local holiday'],
#    'locations': 'EX',
#    'states': [{'id': 296,
#      'abbrev': 'EX',
#      'name': 'Extremadura',
#      'exception': None,
#      'iso': 'es-ex'}]},
#   {'name': 'Virgin of the Victory',
#    'description': None,
#    'date': {'iso': '2019-09-08',
#     'datetime': {'year': 2019, 'month': 9, 'day': 8}},
#    'type': ['Local holiday'],
#    'locations': 'ML',
#    'states': [{'id': 304,
#      'abbrev': 'ML',
#      'name': 'Melilla',
#      'exception': None,
#      'iso': 'es-ml'}]},
#   {'name': 'Day of Asturias observed',
#    'description': 'The Day of Asturias commemorates the Virgin of Covadonga and the Battle of Covadonga. It is an annual local public holiday in the autonomous community of Asturias in Spain on September 8.',
#    'date': {'iso': '2019-09-09',
#     'datetime': {'year': 2019, 'month': 9, 'day': 9}},
#    'type': ['Local holiday'],
#    'locations': 'O',
#    'states': [{'id': 288,
#      'abbrev': 'O',
#      'name': 'Asturias',
#      'exception': None,
#      'iso': 'es-as'}]},
#   {'name': 'Day of Extremadura observed',
#    'description': "The Day of Extremadura marks the anniversary of the Virgin Mary's birth. It is a local public holiday in Extremadura, Spain, on September 8.",
#    'date': {'iso': '2019-09-09',
#     'datetime': {'year': 2019, 'month': 9, 'day': 9}},
#    'type': ['Local holiday'],
#    'locations': 'EX',
#    'states': [{'id': 296,
#      'abbrev': 'EX',
#      'name': 'Extremadura',
#      'exception': None,
#      'iso': 'es-ex'}]},
#   {'name': 'Virgin of the Victory observed',
#    'description': None,
#    'date': {'iso': '2019-09-09',
#     'datetime': {'year': 2019, 'month': 9, 'day': 9}},
#    'type': ['Local holiday'],
#    'locations': 'ML',
#    'states': [{'id': 304,
#      'abbrev': 'ML',
#      'name': 'Melilla',
#      'exception': None,
#      'iso': 'es-ml'}]},
#   {'name': 'Day of Catalonia',
#    'description': 'The Day of Catalonia commemorates the end of the siege of Barcelona in 1714. It is a local public holiday in Barcelona, Spain, on September 11.',
#    'date': {'iso': '2019-09-11',
#     'datetime': {'year': 2019, 'month': 9, 'day': 11}},
#    'type': ['Local holiday'],
#    'locations': 'CT',
#    'states': [{'id': 295,
#      'abbrev': 'CT',
#      'name': 'Catalonia',
#      'exception': None,
#      'iso': 'es-ct'}]},
#   {'name': 'Nuestra Señora de la Bien Aparecida',
#    'description': None,
#    'date': {'iso': '2019-09-15',
#     'datetime': {'year': 2019, 'month': 9, 'day': 15}},
#    'type': ['Local holiday'],
#    'locations': 'S',
#    'states': [{'id': 292,
#      'abbrev': 'S',
#      'name': 'Cantabria',
#      'exception': None,
#      'iso': 'es-cb'}]},
#   {'name': 'Day of Melilla',
#    'description': 'The Day of Melilla marks the anniversary of the storming of the city in 1497 and is a public holiday in Melilla, Spain.',
#    'date': {'iso': '2019-09-17',
#     'datetime': {'year': 2019, 'month': 9, 'day': 17}},
#    'type': ['Local holiday'],
#    'locations': 'ML',
#    'states': [{'id': 304,
#      'abbrev': 'ML',
#      'name': 'Melilla',
#      'exception': None,
#      'iso': 'es-ml'}]},
#   {'name': 'September Equinox',
#    'description': None,
#    'date': {'iso': '2019-09-23T09:50:13+02:00',
#     'datetime': {'year': 2019,
#      'month': 9,
#      'day': 23,
#      'hour': 9,
#      'minute': 50,
#      'second': 13},
#     'timezone': {'offset': '+02:00',
#      'zoneabb': 'CEST',
#      'zoneoffset': 3600,
#      'zonedst': 3600,
#      'zonetotaloffset': 7200}},
#    'type': ['Season'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Day of the Valencian Community',
#    'description': 'The Day of the Valencian Community is a local public holiday in Valencia, Spain, on October 9 each year. It celebrates Valencian culture and history.',
#    'date': {'iso': '2019-10-09',
#     'datetime': {'year': 2019, 'month': 10, 'day': 9}},
#    'type': ['Local holiday'],
#    'locations': 'VC',
#    'states': [{'id': 302,
#      'abbrev': 'VC',
#      'name': 'Valencia',
#      'exception': None,
#      'iso': 'es-vc'}]},
#   {'name': 'Hispanic Day',
#    'description': 'Hispanic Day marks the anniversary of the date that Christopher Columbus first set foot in the Americas. It is a public holiday in Spain on October 12.',
#    'date': {'iso': '2019-10-12',
#     'datetime': {'year': 2019, 'month': 10, 'day': 12}},
#    'type': ['National holiday'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Daylight Saving Time ends',
#    'description': None,
#    'date': {'iso': '2019-10-27T03:00:00+02:00',
#     'datetime': {'year': 2019,
#      'month': 10,
#      'day': 27,
#      'hour': 3,
#      'minute': 0,
#      'second': 0},
#     'timezone': {'offset': '+02:00',
#      'zoneabb': 'CEST',
#      'zoneoffset': 3600,
#      'zonedst': 3600,
#      'zonetotaloffset': 7200}},
#    'type': ['Clock change/Daylight Saving Time'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': "All Saints' Day",
#    'description': "Many churches honor all their saints on All Saints' Day, also known as All Hallows' Day.",
#    'date': {'iso': '2019-11-01',
#     'datetime': {'year': 2019, 'month': 11, 'day': 1}},
#    'type': ['National holiday'],
#    'locations': 'CL, AN, AR, O, EX, CN, S, CE, M, ML',
#    'states': [{'id': 294,
#      'abbrev': 'CL',
#      'name': 'Castile-Leon',
#      'exception': None,
#      'iso': 'es-cl'},
#     {'id': 212,
#      'abbrev': 'AN',
#      'name': 'Andalusia',
#      'exception': None,
#      'iso': 'es-an'},
#     {'id': 213,
#      'abbrev': 'AR',
#      'name': 'Aragon',
#      'exception': None,
#      'iso': 'es-ar'},
#     {'id': 288,
#      'abbrev': 'O',
#      'name': 'Asturias',
#      'exception': None,
#      'iso': 'es-as'},
#     {'id': 296,
#      'abbrev': 'EX',
#      'name': 'Extremadura',
#      'exception': None,
#      'iso': 'es-ex'},
#     {'id': 291,
#      'abbrev': 'CN',
#      'name': 'Canary Islands',
#      'exception': None,
#      'iso': 'es-cn'},
#     {'id': 292,
#      'abbrev': 'S',
#      'name': 'Cantabria',
#      'exception': None,
#      'iso': 'es-cb'},
#     {'id': 303,
#      'abbrev': 'CE',
#      'name': 'Ceuta',
#      'exception': None,
#      'iso': 'es-ce'},
#     {'id': 299,
#      'abbrev': 'M',
#      'name': 'Madrid',
#      'exception': None,
#      'iso': 'es-md'},
#     {'id': 304,
#      'abbrev': 'ML',
#      'name': 'Melilla',
#      'exception': None,
#      'iso': 'es-ml'}]},
#   {'name': "All Saints' Day",
#    'description': "Many churches honor all their saints on All Saints' Day, also known as All Hallows' Day.",
#    'date': {'iso': '2019-11-01',
#     'datetime': {'year': 2019, 'month': 11, 'day': 1}},
#    'type': ['National holiday'],
#    'locations': 'All except AN, AR, O, CN, S, CL, EX, M, ML',
#    'states': [{'id': 289,
#      'abbrev': 'IB',
#      'name': 'Balearic Islands',
#      'exception': None,
#      'iso': 'es-ib'},
#     {'id': 290,
#      'abbrev': 'PV',
#      'name': 'Basque Country',
#      'exception': None,
#      'iso': 'es-pv'},
#     {'id': 293,
#      'abbrev': 'CM',
#      'name': 'Castile-La Mancha',
#      'exception': None,
#      'iso': 'es-cm'},
#     {'id': 295,
#      'abbrev': 'CT',
#      'name': 'Catalonia',
#      'exception': None,
#      'iso': 'es-ct'},
#     {'id': 297,
#      'abbrev': 'GA',
#      'name': 'Galicia',
#      'exception': None,
#      'iso': 'es-ga'},
#     {'id': 298,
#      'abbrev': 'LO',
#      'name': 'La Rioja',
#      'exception': None,
#      'iso': 'es-ri'},
#     {'id': 300,
#      'abbrev': 'MU',
#      'name': 'Murcia',
#      'exception': None,
#      'iso': 'es-mc'},
#     {'id': 301,
#      'abbrev': 'NA',
#      'name': 'Navarre',
#      'exception': None,
#      'iso': 'es-nc'},
#     {'id': 302,
#      'abbrev': 'VC',
#      'name': 'Valencia',
#      'exception': None,
#      'iso': 'es-vc'},
#     {'id': 303,
#      'abbrev': 'CE',
#      'name': 'Ceuta',
#      'exception': None,
#      'iso': 'es-ce'},
#     {'id': 306,
#      'abbrev': 'VI',
#      'name': 'Álava',
#      'exception': None,
#      'iso': 'es-vi'},
#     {'id': 307,
#      'abbrev': 'AB',
#      'name': 'Albacete',
#      'exception': None,
#      'iso': 'es-ab'},
#     {'id': 308,
#      'abbrev': 'A',
#      'name': 'Alicante',
#      'exception': None,
#      'iso': 'es-a'},
#     {'id': 309,
#      'abbrev': 'AL',
#      'name': 'Almería',
#      'exception': None,
#      'iso': 'es-al'},
#     {'id': 310,
#      'abbrev': 'O',
#      'name': 'Asturias',
#      'exception': None,
#      'iso': 'es-o'},
#     {'id': 311,
#      'abbrev': 'AV',
#      'name': 'Ávila',
#      'exception': None,
#      'iso': 'es-av'},
#     {'id': 312,
#      'abbrev': 'BA',
#      'name': 'Badajoz',
#      'exception': None,
#      'iso': 'es-ba'},
#     {'id': 313,
#      'abbrev': 'PM',
#      'name': 'Baleares',
#      'exception': None,
#      'iso': 'es-pm'},
#     {'id': 314,
#      'abbrev': 'B',
#      'name': 'Barcelona',
#      'exception': None,
#      'iso': 'es-b'},
#     {'id': 315,
#      'abbrev': 'BU',
#      'name': 'Burgos',
#      'exception': None,
#      'iso': 'es-bu'},
#     {'id': 316,
#      'abbrev': 'CC',
#      'name': 'Cáceres',
#      'exception': None,
#      'iso': 'es-cc'},
#     {'id': 317,
#      'abbrev': 'CA',
#      'name': 'Cádiz',
#      'exception': None,
#      'iso': 'es-ca'},
#     {'id': 318,
#      'abbrev': 'S',
#      'name': 'Cantabria',
#      'exception': None,
#      'iso': 'es-s'},
#     {'id': 319,
#      'abbrev': 'CS',
#      'name': 'Castellón',
#      'exception': None,
#      'iso': 'es-cs'},
#     {'id': 320,
#      'abbrev': 'CR',
#      'name': 'Ciudad Real',
#      'exception': None,
#      'iso': 'es-cr'},
#     {'id': 321,
#      'abbrev': 'CO',
#      'name': 'Córdoba',
#      'exception': None,
#      'iso': 'es-co'},
#     {'id': 322,
#      'abbrev': 'CU',
#      'name': 'Cuenca',
#      'exception': None,
#      'iso': 'es-cu'},
#     {'id': 323,
#      'abbrev': 'GI',
#      'name': 'Girona',
#      'exception': None,
#      'iso': 'es-gi'},
#     {'id': 324,
#      'abbrev': 'GR',
#      'name': 'Granada',
#      'exception': None,
#      'iso': 'es-gr'},
#     {'id': 325,
#      'abbrev': 'GU',
#      'name': 'Guadalajara',
#      'exception': None,
#      'iso': 'es-gu'},
#     {'id': 326,
#      'abbrev': 'SS',
#      'name': 'Guipúzcoa',
#      'exception': None,
#      'iso': 'es-ss'},
#     {'id': 327,
#      'abbrev': 'H',
#      'name': 'Huelva',
#      'exception': None,
#      'iso': 'es-h'},
#     {'id': 328,
#      'abbrev': 'HU',
#      'name': 'Huesca',
#      'exception': None,
#      'iso': 'es-hu'},
#     {'id': 329,
#      'abbrev': 'J',
#      'name': 'Jaén',
#      'exception': None,
#      'iso': 'es-j'},
#     {'id': 330,
#      'abbrev': 'C',
#      'name': 'A Coruña',
#      'exception': None,
#      'iso': 'es-c'},
#     {'id': 331,
#      'abbrev': 'LO',
#      'name': 'La Rioja',
#      'exception': None,
#      'iso': 'es-lo'},
#     {'id': 332,
#      'abbrev': 'GC',
#      'name': 'Las Palmas',
#      'exception': None,
#      'iso': 'es-gc'},
#     {'id': 333,
#      'abbrev': 'LE',
#      'name': 'León',
#      'exception': None,
#      'iso': 'es-le'},
#     {'id': 334,
#      'abbrev': 'L',
#      'name': 'Lleida',
#      'exception': None,
#      'iso': 'es-l'},
#     {'id': 335,
#      'abbrev': 'LU',
#      'name': 'Lugo',
#      'exception': None,
#      'iso': 'es-lu'},
#     {'id': 336,
#      'abbrev': 'M',
#      'name': 'Madrid',
#      'exception': None,
#      'iso': 'es-m'},
#     {'id': 337,
#      'abbrev': 'MA',
#      'name': 'Málaga',
#      'exception': None,
#      'iso': 'es-ma'},
#     {'id': 338,
#      'abbrev': 'MU',
#      'name': 'Murcia',
#      'exception': None,
#      'iso': 'es-mu'},
#     {'id': 339,
#      'abbrev': 'NA',
#      'name': 'Navarre',
#      'exception': None,
#      'iso': 'es-na'},
#     {'id': 340,
#      'abbrev': 'OR',
#      'name': 'Ourense',
#      'exception': None,
#      'iso': 'es-or'},
#     {'id': 341,
#      'abbrev': 'P',
#      'name': 'Palencia',
#      'exception': None,
#      'iso': 'es-p'},
#     {'id': 342,
#      'abbrev': 'PO',
#      'name': 'Pontevedra',
#      'exception': None,
#      'iso': 'es-po'},
#     {'id': 343,
#      'abbrev': 'SA',
#      'name': 'Salamanca',
#      'exception': None,
#      'iso': 'es-sa'},
#     {'id': 344,
#      'abbrev': 'TF',
#      'name': 'Santa Cruz De Tenerife',
#      'exception': None,
#      'iso': 'es-tf'},
#     {'id': 345,
#      'abbrev': 'SG',
#      'name': 'Segovia',
#      'exception': None,
#      'iso': 'es-sg'},
#     {'id': 346,
#      'abbrev': 'SE',
#      'name': 'Seville',
#      'exception': None,
#      'iso': 'es-se'},
#     {'id': 347,
#      'abbrev': 'SO',
#      'name': 'Soria',
#      'exception': None,
#      'iso': 'es-so'},
#     {'id': 348,
#      'abbrev': 'T',
#      'name': 'Tarragona',
#      'exception': None,
#      'iso': 'es-t'},
#     {'id': 349,
#      'abbrev': 'TE',
#      'name': 'Teruel',
#      'exception': None,
#      'iso': 'es-te'},
#     {'id': 350,
#      'abbrev': 'TO',
#      'name': 'Toledo',
#      'exception': None,
#      'iso': 'es-to'},
#     {'id': 351,
#      'abbrev': 'V',
#      'name': 'Valencia',
#      'exception': None,
#      'iso': 'es-v'},
#     {'id': 352,
#      'abbrev': 'VA',
#      'name': 'Valladolid',
#      'exception': None,
#      'iso': 'es-va'},
#     {'id': 353,
#      'abbrev': 'BI',
#      'name': 'Vizcaya',
#      'exception': None,
#      'iso': 'es-bi'},
#     {'id': 354,
#      'abbrev': 'ZA',
#      'name': 'Zamora',
#      'exception': None,
#      'iso': 'es-za'},
#     {'id': 355,
#      'abbrev': 'Z',
#      'name': 'Zaragoza',
#      'exception': None,
#      'iso': 'es-z'}]},
#   {'name': 'Day of Navarre',
#    'description': 'People celebrate the culture of the Navarre region in Spain and life of Saint Francis Xavier on the Day of Navarre. It is an annual local public holiday in this region on December 3.',
#    'date': {'iso': '2019-12-03',
#     'datetime': {'year': 2019, 'month': 12, 'day': 3}},
#    'type': ['Local holiday'],
#    'locations': 'NA',
#    'states': [{'id': 301,
#      'abbrev': 'NA',
#      'name': 'Navarre',
#      'exception': None,
#      'iso': 'es-nc'}]},
#   {'name': 'Constitution Day',
#    'description': 'Constitution Day marks the anniversary of the referendum to approve the Spanish Constitution and is a public holiday in Spain.',
#    'date': {'iso': '2019-12-06',
#     'datetime': {'year': 2019, 'month': 12, 'day': 6}},
#    'type': ['National holiday'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Immaculate Conception',
#    'description': 'The Feast of the Immaculate Conception is a Christian observance on December 8 each year.',
#    'date': {'iso': '2019-12-08',
#     'datetime': {'year': 2019, 'month': 12, 'day': 8}},
#    'type': ['National holiday'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Immaculate Conception observed',
#    'description': None,
#    'date': {'iso': '2019-12-09',
#     'datetime': {'year': 2019, 'month': 12, 'day': 9}},
#    'type': ['National holiday'],
#    'locations': 'AN, AR, O, S, CL, EX, M, LO, ML',
#    'states': [{'id': 212,
#      'abbrev': 'AN',
#      'name': 'Andalusia',
#      'exception': None,
#      'iso': 'es-an'},
#     {'id': 213,
#      'abbrev': 'AR',
#      'name': 'Aragon',
#      'exception': None,
#      'iso': 'es-ar'},
#     {'id': 288,
#      'abbrev': 'O',
#      'name': 'Asturias',
#      'exception': None,
#      'iso': 'es-as'},
#     {'id': 292,
#      'abbrev': 'S',
#      'name': 'Cantabria',
#      'exception': None,
#      'iso': 'es-cb'},
#     {'id': 294,
#      'abbrev': 'CL',
#      'name': 'Castile-Leon',
#      'exception': None,
#      'iso': 'es-cl'},
#     {'id': 296,
#      'abbrev': 'EX',
#      'name': 'Extremadura',
#      'exception': None,
#      'iso': 'es-ex'},
#     {'id': 299,
#      'abbrev': 'M',
#      'name': 'Madrid',
#      'exception': None,
#      'iso': 'es-md'},
#     {'id': 298,
#      'abbrev': 'LO',
#      'name': 'La Rioja',
#      'exception': None,
#      'iso': 'es-ri'},
#     {'id': 304,
#      'abbrev': 'ML',
#      'name': 'Melilla',
#      'exception': None,
#      'iso': 'es-ml'}]},
#   {'name': 'December Solstice',
#    'description': None,
#    'date': {'iso': '2019-12-22T05:19:26+01:00',
#     'datetime': {'year': 2019,
#      'month': 12,
#      'day': 22,
#      'hour': 5,
#      'minute': 19,
#      'second': 26},
#     'timezone': {'offset': '+01:00',
#      'zoneabb': 'CET',
#      'zoneoffset': 3600,
#      'zonedst': 0,
#      'zonetotaloffset': 3600}},
#    'type': ['Season'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Christmas Eve',
#    'description': 'Christmas Eve is the day before Christmas Day and falls on December 24 in the Gregorian calendar.',
#    'date': {'iso': '2019-12-24',
#     'datetime': {'year': 2019, 'month': 12, 'day': 24}},
#    'type': ['Observance'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': 'Christmas Day',
#    'description': 'Christmas Day is one of the biggest Christian celebrations and falls on December 25 in the Gregorian calendar.',
#    'date': {'iso': '2019-12-25',
#     'datetime': {'year': 2019, 'month': 12, 'day': 25}},
#    'type': ['National holiday'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': "St Stephen's Day",
#    'description': 'The Feast of St Stephen is a holiday to commemorate the life and death of an early Christian saint.',
#    'date': {'iso': '2019-12-26',
#     'datetime': {'year': 2019, 'month': 12, 'day': 26}},
#    'type': ['Local holiday'],
#    'locations': 'IB, CT',
#    'states': [{'id': 289,
#      'abbrev': 'IB',
#      'name': 'Balearic Islands',
#      'exception': None,
#      'iso': 'es-ib'},
#     {'id': 295,
#      'abbrev': 'CT',
#      'name': 'Catalonia',
#      'exception': None,
#      'iso': 'es-ct'}]},
#   {'name': 'Feast of the Holy Family',
#    'description': None,
#    'date': {'iso': '2019-12-29',
#     'datetime': {'year': 2019, 'month': 12, 'day': 29}},
#    'type': ['Observance'],
#    'locations': 'All',
#    'states': 'All'},
#   {'name': "New Year's Eve",
#    'description': 'New Year’s Eve is the last day of the year, December 31, in the Gregorian calendar.',
#    'date': {'iso': '2019-12-31',
#     'datetime': {'year': 2019, 'month': 12, 'day': 31}},
#    'type': ['Observance'],
#    'locations': 'All',
#    'states': 'All'}]}
