# %% [markdown]
# # Pipelines project

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Este trabajo consiste en un estudio de las causas de muerte en Estados Unidos en el año 2015. Vamos a ver el DataFrame con el que vamos a trabajar así como otra tabla que corresponde a los códigos de causas de muerte de la primera tabla.

# %%
data = pd.read_csv('./2015_data.csv')
# Out:
# /home/marta/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (40,41,42,43,61,62,63,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
death = data.copy()

# %%
display(death.head())
# Out:
#    resident_status  education_1989_revision  education_2003_revision  \
# 0                1                      NaN                      3.0
# 1                1                      NaN                      6.0
# 2                1                      NaN                      3.0
# 3                1                      NaN                      3.0
# 4                1                      NaN                      5.0
#
#    education_reporting_flag  month_of_death sex  detail_age_type  detail_age  \
# 0                         1               1   M                1          84
# 1                         1               1   M                1          70
# 2                         1               1   F                1          91
# 3                         1               1   F                1          40
# 4                         1               1   F                1          89
#
#    age_substitution_flag  age_recode_52  ...  record_condition_18  \
# ...

# %% [markdown]
# En primer lugar, vamos a observar la tabla con más detenimiento.

# %%
death.columns
# Out:
# Index(['resident_status', 'education_1989_revision', 'education_2003_revision',
#        'education_reporting_flag', 'month_of_death', 'sex', 'detail_age_type',
#        'detail_age', 'age_substitution_flag', 'age_recode_52', 'age_recode_27',
#        'age_recode_12', 'infant_age_recode_22',
#        'place_of_death_and_decedents_status', 'marital_status',
#        'day_of_week_of_death', 'current_data_year', 'injury_at_work',
#        'manner_of_death', 'method_of_disposition', 'autopsy', 'activity_code',
#        'place_of_injury_for_causes_w00_y34_except_y06_and_y07_',
#        'icd_code_10th_revision', '358_cause_recode', '113_cause_recode',
#        '130_infant_cause_recode', '39_cause_recode',
#        'number_of_entity_axis_conditions', 'entity_condition_1',
#        'entity_condition_2', 'entity_condition_3', 'entity_condition_4',
#        'entity_condition_5', 'entity_condition_6', 'entity_condition_7',
# ...

# %%
death.isnull().sum()
# Out:
# resident_status                                                 0
# education_1989_revision                                   2645155
# education_2003_revision                                     73043
# education_reporting_flag                                        0
# month_of_death                                                  0
# sex                                                             0
# detail_age_type                                                 0
# detail_age                                                      0
# age_substitution_flag                                     2718185
# age_recode_52                                                   0
# age_recode_27                                                   0
# age_recode_12                                                   0
# infant_age_recode_22                                      2694672
# place_of_death_and_decedents_status                             0
# ...

# %%
col_malas=death.drop(columns = ['current_data_year','injury_at_work','autopsy','icd_code_10th_revision','358_cause_recode','113_cause_recode'], axis=1)
death = col_malas
(death.head())
# Out:
#    resident_status  education_1989_revision  education_2003_revision  \
# 0                1                      NaN                      3.0
# 1                1                      NaN                      6.0
# 2                1                      NaN                      3.0
# 3                1                      NaN                      3.0
# 4                1                      NaN                      5.0
#
#    education_reporting_flag  month_of_death sex  detail_age_type  detail_age  \
# 0                         1               1   M                1          84
# 1                         1               1   M                1          70
# 2                         1               1   F                1          91
# 3                         1               1   F                1          40
# 4                         1               1   F                1          89
#
#    age_substitution_flag  age_recode_52  ...  record_condition_18  \
# ...

# %%
death.columns
# Out:
# Index(['resident_status', 'education_1989_revision', 'education_2003_revision',
#        'education_reporting_flag', 'month_of_death', 'sex', 'detail_age_type',
#        'detail_age', 'age_substitution_flag', 'age_recode_52', 'age_recode_27',
#        'age_recode_12', 'infant_age_recode_22',
#        'place_of_death_and_decedents_status', 'marital_status',
#        'day_of_week_of_death', 'manner_of_death', 'method_of_disposition',
#        'activity_code',
#        'place_of_injury_for_causes_w00_y34_except_y06_and_y07_',
#        '130_infant_cause_recode', '39_cause_recode',
#        'number_of_entity_axis_conditions', 'entity_condition_1',
#        'entity_condition_2', 'entity_condition_3', 'entity_condition_4',
#        'entity_condition_5', 'entity_condition_6', 'entity_condition_7',
#        'entity_condition_8', 'entity_condition_9', 'entity_condition_10',
#        'entity_condition_11', 'entity_condition_12', 'entity_condition_13',
# ...

# %%
death.dtypes
# Out:
# resident_status                                             int64
# education_1989_revision                                   float64
# education_2003_revision                                   float64
# education_reporting_flag                                    int64
# month_of_death                                              int64
# sex                                                        object
# detail_age_type                                             int64
# detail_age                                                  int64
# age_substitution_flag                                     float64
# age_recode_52                                               int64
# age_recode_27                                               int64
# age_recode_12                                               int64
# infant_age_recode_22                                      float64
# place_of_death_and_decedents_status                         int64
# ...

# %%
#death = death.rename('39_cause_recode':'Cause of Death', inplace=True)

#death

# %%
#df.rename(index=str, columns={"A": "a", "C": "c"})
death = death.rename(index=str, columns={"39_cause_recode": 'Cause of death'})
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-13f576df1ebd> in <module>
#       1 #df.rename(index=str, columns={"A": "a", "C": "c"})
# ----> 2 death = death.rename(index=str, columns={"39_cause_recode": 'Cause of death'})
#
# ~/.local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     195         @wraps(func)
#     196         def wrapper(*args, **kwargs):
# --> 197             return func(*args, **kwargs)
#     198
#     199         if not PY2:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in rename(self, *args, **kwargs)
#    4023         kwargs.pop('axis', None)
#    4024         kwargs.pop('mapper', None)
# -> 4025         return super(DataFrame, self).rename(**kwargs)
#    4026
#    4027     @Substitution(**_shared_doc_kwargs)
#
# ...

# %%
#eath = death.rename({'39_cause_recode':'Cause of Death'},inplace = True)
death.rendk, columns={"A": "a", "C": "c"})

# %%
causes = pd.read_csv('./CauseRecode39.csv')

# %% [markdown]
# Disponemos del nombre de las enfermedades, que están codificadas en la tabla de arriba.

# %%
causes
# Out:
#     Code                                        Description
# 0      1                                       Tuberculosis
# 1      2                                           Syphilis
# 2      3                                                HIV
# 3      5                      Malignant neoplasm of stomach
# 4      6      Malignant neoplasms of colon, rectum and anus
# 5      7                     Malignant neoplasm of pancreas
# 6      8  Malignant neoplasms of trachea, bronchus and lung
# 7      9                       Malignant neoplasm of breast
# 8     10  Malignant neoplasms of cervix uteri, corpus ut...
# 9     11                     Malignant neoplasm of prostate
# 10    12                Malignant neoplasms of urinary trac
# 11    13                             Non-Hodgkin's lymphoma
# 12    14                                           Leukemia
# 13    15                          Other malignant neoplasms
# 14    16                                  Diabetes mellitus
# ...

# %% [markdown]
# Ahora podemos proceder a sustituir los números (códigos) por los nombres de causas de muerte que nos interesan. Para este estudio nos centraremos en las causas de muerte siguientes: enfermedades cardiacas, cáncer, tráfico y homicidios.

# %%
def homog_causes (v):

    cause_recode = {

        "16":"Heart diseases", 
        "17":"Heart diseases", 
        "18":"Heart diseases", 
        "3":"Cancer", 
        "4 ":"Cancer", 
        "5":"Cancer",
        "6":"Cancer",
        "7":"Cancer",
        "8":"Cancer",
        "9":"Cancer",
        "10":"Cancer",
        "11":"Cancer",
        "12":"Cancer",
        "13":"Cancer",
        "37":"Motor vehicle accidents",
        "36":"Homicide",
        

    }

    for death, fila in death.items(): 

        if death in v: 

            return fila

    return None

# %%
death
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8b7b4d105c4f> in <module>
# ----> 1 death
#
# NameError: name 'death' is not defined
